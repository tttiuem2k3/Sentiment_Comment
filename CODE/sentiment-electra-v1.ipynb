# %%
# --------------------- Import các thư viện cần thiết ---------------------

from tqdm import tqdm  #Hiển thị thanh tiến trình.
import time            #Đo thời gian thực thi.
from sklearn.model_selection import train_test_split
import pandas as pd
import torch
from transformers import ElectraForSequenceClassification, ElectraTokenizer, ElectraModel #Thư viện cung cấp mô hình pre-trained như ELECTRA.
from torch.optim import AdamW
import torch.nn as nn
from torch.optim import lr_scheduler
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, GradScaler
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import Counter
from sklearn.metrics import classification_report, confusion_matrix

# %%
#----------------------Xử lý data-Chia tập dữ liệu huấn luyện---------------------------------


# Đọc dataset đã qua tiền xử lý dữ liệu
data_df = pd.read_csv('/kaggle/input/dataset-sentiment-v5/dataset_process_v5.csv')


# Đảm bảo comment là chuỗi
data_df['comment'] = [str(text) for text in data_df['comment']]

# Đảm bảo nhãn là kiểu số nguyên
data_df['label'] = data_df['label'].astype(int)

print("\nTổng số lượng comment: ",len(data_df))

def split_data(df, split_size):
    train_size = int(split_size[0] * len(df))
    val_size = int(split_size[1] * len(df))

    df_train = df[:train_size]
    df_val = df[train_size:train_size+val_size]
    df_test = df[train_size + val_size:]
    return df_train, df_val, df_test

# Chia tập dữ liệu
split = [0.7, 0.15, 0.15]
train_data, val_data, test_data = split_data(data_df, split)


print("\nSố lượng dữ liệu trong tập train:", len(train_data))
print(train_data[0:20])
print("\nSố lượng dữ liệu trong tập validation:", len(val_data))
print(val_data[0:5])
print("\nSố lượng dữ liệu trong tập test:", len(test_data))
print(test_data[0:5])
# Out:
# Tổng số lượng comment:  34468
#
# Số lượng dữ liệu trong tập train: 24127
#                                               comment  label
# 0   hàng đẹp vừa giá tiền nhưng k biết bên trong g...      0
# 1   chất_lượng sản_phẩm rất kémshop giao hàng đã q...      1
# 2   máy êm dùng tốt k bit cách sử_dụng nhiệt_tình ...      0
# 3   tiền_nào_của_đó giao đôi giầy hai hãng khác nh...      1
# 4                                            cứng quá      1
# 5   thời_gian giao hàng rất nhanh của em bị nhầm t...      1
# 6   mua gần chục đôi giao hàng lỗi gọi ko trả_lời ...      1
# 7   thời_gian giao hàng rất nhanh nhân_viên giao h...      0
# 8                ko thích chất_lượng sản_phẩm rất kém      1
# 9   chất_lượng sản_phẩm tuyệt_vời rất phù_hợp giá ...      0
# 10  bán hàng tư_vấn dễ_thương lần mua cũng có quà ...      0
# 11  chữ đọc được chữ không thấy                   ...      1
# 12  đóng_gói sản_phẩm kém giao hàng ko đúng màu nh...      1
# 13                                không đúng sản_phẩm      1
# 14              rất ưng chất_lượng sản_phẩm tuyệt_vời      0
# 15  chất_lượng âm_thanh kém hỏng sau 3 ngày sử_dụn...      1
# 16  sản_phẩm hộp bì trầy_trụa đã từng bị khui từng...      1
# 17             nhìn như đồ fake mua 1k nên k phàn_nàn      1
# 18                          bán hàng không nhiệt_tình      1
# 19  vì_vậy nhưng tờ hướng_dẫn sử_dụng bằng tiếng n...      1
#
# Số lượng dữ liệu trong tập validation: 5170
#                                                  comment  label
# 24127  chất_lượng sản_phẩm tuyệt_vời chuẩn ko bpa ko ...      0
# 24128  chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩ...      0
# 24129  chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩ...      0
# 24130  giao hàng nhanh cl sp tuyệt_vời nhưng giáo thi...      0
# 24131                          chất_lượng phù_hợp giá_cả      0
#
# Số lượng dữ liệu trong tập test: 5171
#                                                  comment  label
# 29297  quyển k hay lắmmình đã từng đọc quyển như thế_...      1
# 29298                                 tạm chấp_nhận được      0
# 29299  không check dc mã_vạch  ko có nhãn bằng tiếng ...      1
# 29300  cảm_nhận ban_đầu khá ổn nhưng dùng được 1 tuần...      1
# 29301          đóng_gói sp xấu ngoài nhìn k đẹp như hình      1

# %%
# --------------------- 1. Dataset Class ---------------------

class Sentiment_Comment_Dataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=128):
        """
        Khởi tạo dataset với các tham số:
        - texts: Danh sách các văn bản (câu) đầu vào.
        - labels: Danh sách nhãn tương ứng với các văn bản.
        - tokenizer: Tokenizer để mã hóa văn bản.
        - max_length: Độ dài tối đa của mỗi đoạn mã hóa.
        """
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.examples = self.tokenize_texts()  # Tạo danh sách các mẫu dữ liệu

    def tokenize_texts(self):
        """
        Tokenize các văn bản. Mỗi văn bản được mã hóa thành một đoạn duy nhất.
        """
        examples = []
        for text, label in zip(self.texts, self.labels):
            tokenized = self.tokenizer(
                text,
                max_length=self.max_length,
                truncation=True,
                padding="max_length",
                return_tensors="pt"
            )
            examples.append((tokenized["input_ids"].squeeze(0), tokenized["attention_mask"].squeeze(0), label))
        return examples

    def __len__(self):
        """
        Trả về số lượng mẫu trong dataset.
        """
        return len(self.examples)

    def __getitem__(self, idx):
        """
        Trả về một mẫu dữ liệu theo chỉ số.
        """
        input_ids, attention_mask, label = self.examples[idx]
        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask,
            'label': torch.tensor(label, dtype=torch.long)
        }

# %%
# # --------------------- 2. Transformer Model -----------------------

# # Mô hình cơ bản: TransformerELECTRA
# # Sử dụng mô hình ElectraModel để trích xuất đặc trưng.
# # Kết nối với lớp phân loại (nn.Linear) để đưa ra kết quả.
# class TransformerELECTRA(nn.Module):
#     def __init__(self, model_name='google/electra-base-discriminator', num_labels=2):
#         super(TransformerELECTRA, self).__init__()
#         self.electra = ElectraModel.from_pretrained(model_name)
#         self.classifier = nn.Linear(self.electra.config.hidden_size, num_labels)
#         self.dropout = nn.Dropout(0.1)

#     def forward(self, input_ids, attention_mask):
#         outputs = self.electra(input_ids=input_ids, attention_mask=attention_mask)
#         sequence_output = outputs.last_hidden_state
#         cls_token_output = sequence_output[:, 0, :]
#         cls_token_output = self.dropout(cls_token_output)
#         logits = self.classifier(cls_token_output)
#         return logits


# Mô hình cải tiến: CustomELECTRAModel
# Thêm cơ chế Attention để trọng số hóa các đặc trưng quan trọng: self.attention = nn.MultiheadAttention(...)
# Lớp LayerNorm cải thiện ổn định trong huấn luyện.
class CustomELECTRAModel(nn.Module):
    def __init__(self, model_name, num_labels=2):
        super(CustomELECTRAModel, self).__init__()
        self.electra = ElectraModel.from_pretrained(model_name)
        self.attention = nn.MultiheadAttention(
            embed_dim=self.electra.config.hidden_size, 
            num_heads=8, 
            batch_first=True
        )
        self.fc1 = nn.Linear(self.electra.config.hidden_size, 128)
        self.fc2 = nn.Linear(128, num_labels)
        self.dropout = nn.Dropout(0.4)
        
        # Thêm lớp LayerNorm
        self.layer_norm = nn.LayerNorm(128)

    def forward(self, input_ids, attention_mask):
        # Trích xuất embeddings từ ELECTRA
        outputs = self.electra(input_ids=input_ids, attention_mask=attention_mask)
        hidden_states = outputs.last_hidden_state  # Shape: (batch_size, seq_len, hidden_size)

        # Attention pooling
        attn_output, _ = self.attention(hidden_states, hidden_states, hidden_states, key_padding_mask=~attention_mask.bool())
        
        # Chọn CLS token làm đặc trưng đại diện
        cls_token_output = attn_output[:, 0, :]  # CLS token tương ứng với đầu tiên của sequence output

        # Fully connected layers
        pooled_output = self.dropout(cls_token_output)  # Áp dụng dropout
        fc1_output = torch.relu(self.fc1(pooled_output))
        
        # Áp dụng Layer Normalization sau FC1
        fc1_output = self.layer_norm(fc1_output)
        
        logits = self.fc2(fc1_output)
        return logits


# --------------------- 3. Trainer Class -----------------------------------------

# Tập trung vào huấn luyện và đánh giá mô hình.
class ClassifierTrainer:
    def __init__(self, model, train_dataloader, val_dataloader, device, lr=2e-5, epochs=3, accumulation_steps=4, checkpoint_dir="/kaggle/working/"):
        self.model = model
        self.train_dataloader = train_dataloader
        self.val_dataloader = val_dataloader
        self.device = device
        self.lr = lr
        self.epochs = epochs
        self.accumulation_steps = accumulation_steps
        self.optimizer = AdamW(self.model.parameters(), lr=self.lr)
        self.scheduler = lr_scheduler.StepLR(self.optimizer, step_size=1, gamma=0.9)
        self.criterion = nn.CrossEntropyLoss()
        self.scaler = torch.amp.GradScaler()  # Mixed Precision
        self.checkpoint_dir = checkpoint_dir
        os.makedirs(checkpoint_dir, exist_ok=True)

        # Lưu loss và accuracy để vẽ biểu đồ
        self.train_losses = []
        self.train_accuracies = []
        self.val_losses = []
        self.val_accuracies = []

    # Huấn luyện một epoch
    # Chạy từng batch dữ liệu qua mô hình.
    # Tính toán và tối ưu hóa loss.
    # Sử dụng autocast và GradScaler để tăng tốc với Mixed Precision.
    def train_one_epoch(self, epoch):
        self.model.train()
        total_loss, total_correct = 0, 0
        previous_percent = 0  # Biến lưu trữ tiến độ trước đó
    
        print(f"Epoch {epoch + 1}: Training...")
        start_time = time.time()

        for step, batch in enumerate(self.train_dataloader):
            input_ids = batch['input_ids'].to(self.device)
            attention_mask = batch['attention_mask'].to(self.device)
            labels = batch['label'].to(self.device)
    
            with torch.amp.autocast(device_type='cuda'):  # Mixed Precision
                logits = self.model(input_ids=input_ids, attention_mask=attention_mask)
                loss = self.criterion(logits, labels) / self.accumulation_steps
    
            self.scaler.scale(loss).backward()
    
            if (step + 1) % self.accumulation_steps == 0 or (step + 1) == len(self.train_dataloader):
                self.scaler.step(self.optimizer)
                self.scaler.update()
                self.optimizer.zero_grad()
    
            total_loss += loss.item() * self.accumulation_steps
            total_correct += (logits.argmax(dim=-1) == labels).sum().item()
    
            # Tính phần trăm hoàn thành
            current_percent = int(100 * (step + 1) / len(self.train_dataloader))
            if current_percent != previous_percent:  # Chỉ in khi phần trăm thay đổi
                previous_percent = current_percent
                avg_loss = total_loss / (step + 1)
                accuracy = total_correct / ((step + 1) * self.train_dataloader.batch_size)
                print(f"Progress: {current_percent}% | Loss: {avg_loss:.4f} | Accuracy: {accuracy:.4f}")

        epoch_time = time.time() - start_time
        print(f"  Training completed in {epoch_time:.2f} seconds.")
        avg_loss = total_loss / len(self.train_dataloader)
        accuracy = total_correct / len(self.train_dataloader.dataset)
        
        # Lưu giá trị loss và accuracy cho vẽ biểu đồ
        self.train_losses.append(avg_loss)
        self.train_accuracies.append(accuracy)
    
        return avg_loss, accuracy

    # Đánh giá mô hình
    # Đánh giá trên tập validation.
    # Tính loss, accuracy và lưu các giá trị để vẽ biểu đồ.
    def evaluate(self, epoch):
        """
        Đánh giá trên tập Validation.
        """
        self.model.eval()
        total_loss, total_correct = 0, 0
        all_labels = []  # Khởi tạo danh sách trống
        all_preds = []   # Khởi tạo danh sách trống
        previous_percent = 0  # Biến lưu trữ tiến độ trước đó
    
        print(f"Epoch {epoch + 1}: Evaluating (Validation)...")
        start_time = time.time()
    
        with torch.no_grad():
            for step, batch in enumerate(self.val_dataloader):
                input_ids = batch['input_ids'].to(self.device)
                attention_mask = batch['attention_mask'].to(self.device)
                labels = batch['label'].to(self.device)
    
                with torch.amp.autocast(device_type='cuda'):
                    logits = self.model(input_ids=input_ids, attention_mask=attention_mask)
                    loss = self.criterion(logits, labels)
    
                total_loss += loss.item()
                total_correct += (logits.argmax(dim=-1) == labels).sum().item()
    
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(logits.argmax(dim=-1).cpu().numpy())
    
                # Tính phần trăm hoàn thành
                current_percent = int(100 * (step + 1) / len(self.val_dataloader))
                if current_percent != previous_percent:  # Chỉ in khi phần trăm thay đổi
                    previous_percent = current_percent
                    avg_loss = total_loss / (step + 1)
                    accuracy = total_correct / ((step + 1) * self.val_dataloader.batch_size)
                    print(f"Progress: {current_percent}% | Loss: {avg_loss:.4f} | Accuracy: {accuracy:.4f}")
    
        epoch_time = time.time() - start_time
        print(f"  Validation completed in {epoch_time:.2f} seconds.")
        avg_loss = total_loss / len(self.val_dataloader)
        accuracy = total_correct / len(self.val_dataloader.dataset)
        
        # Lưu giá trị loss và accuracy cho vẽ biểu đồ
        self.val_losses.append(avg_loss)
        self.val_accuracies.append(accuracy)
    
        return avg_loss, accuracy


    # Hàm huấn luyện
    def train(self):
        best_val_acc = 0.0
        for epoch in range(self.epochs):
            train_loss, train_acc = self.train_one_epoch(epoch)
            val_loss, val_acc = self.evaluate(epoch)

            self.scheduler.step()

            print(f"Epoch {epoch + 1}/{self.epochs}:")
            print(f"  Train Loss: {train_loss:.4f} | Train Accuracy: {train_acc:.4f}")
            print(f"  Val Loss: {val_loss:.4f} | Val Accuracy: {val_acc:.4f}")

            # Lưu mô hình tốt nhất
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                self.save_best_checkpoint(epoch, val_acc)
                
        # Hiển thị kết quả cuối cùng
        final_train_loss = self.train_losses[-1]
        final_train_acc = self.train_accuracies[-1]
        final_val_loss = self.val_losses[-1]
        final_val_acc = self.val_accuracies[-1]
    
        print("\n===== Training Completed =====")
        print(f"Final Train Loss: {final_train_loss:.4f} | Final Train Accuracy: {final_train_acc:.4f}")
        print(f"Final Val Loss: {final_val_loss:.4f} | Final Val Accuracy: {final_val_acc:.4f}")

    # Vẽ biểu đồ Loss và Accuracy theo từng epoch.
    def plot_metrics(self):
        epochs_range = range(1, self.epochs + 1)

        # Vẽ biểu đồ loss
        plt.figure(figsize=(12, 6))
        plt.plot(epochs_range, self.train_losses, label='Train Loss')
        plt.plot(epochs_range, self.val_losses, label='Val Loss')
        plt.title('Loss over Epochs')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.show()

        # Vẽ biểu đồ accuracy
        plt.figure(figsize=(12, 6))
        plt.plot(epochs_range, self.train_accuracies, label='Train Accuracy')
        plt.plot(epochs_range, self.val_accuracies, label='Val Accuracy')
        plt.title('Accuracy over Epochs')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.show()

    # Lưu trạng thái mô hình có độ chính xác cao nhất trên tập validation.
    def save_best_checkpoint(self, epoch, val_acc):
        """
        Lưu checkpoint tốt nhất.
        """
        checkpoint_path = os.path.join(self.checkpoint_dir, f"best_model_epoch_{epoch + 1}_val_acc_{val_acc:.4f}.pth")
        torch.save(self.model, checkpoint_path)
        print(f"  Saved best model to {checkpoint_path}")

# %%
# !pip install ipywidgets --upgrade
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (8.21.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %%
# --------------------- 4. Dataset và Dataloader ---------------------

# Tải mô hình ELECTRA-Base
model_name='google/electra-base-discriminator' 
tokenizer = ElectraTokenizer.from_pretrained(model_name)

# Lưu tokenizer
tokenizer.save_pretrained("/kaggle/working/tokenizer")

train_dataset = Sentiment_Comment_Dataset(
    texts=train_data['comment'].tolist(),
    labels=train_data['label'].tolist(),
    tokenizer=tokenizer
)
print(f"\nSố lượng mẫu train: từ {len(train_data)} mẫu đã tăng lên {len(train_dataset)} mẫu")

val_dataset = Sentiment_Comment_Dataset(
    texts=val_data['comment'].tolist(),
    labels=val_data['label'].tolist(),
    tokenizer=tokenizer
)
print(f"\nSố lượng mẫu val: từ {len(val_data)} mẫu đã tăng lên {len(val_dataset)} mẫu")
#DataLoader Optimization
# Tối ưu hóa DataLoader:
# Sử dụng pin_memory và num_workers để tăng tốc độ nạp dữ liệu.
# Có collate_fn để xử lý batch đầu vào cho mô hình

# Hàm collate_fn , mỗi batch sẽ có 3 trường dữ liệu
def collate_fn(batch):
    input_ids = torch.stack([item['input_ids'] for item in batch])
    attention_mask = torch.stack([item['attention_mask'] for item in batch])
    labels = torch.tensor([item['label'] for item in batch], dtype=torch.long)
    return {'input_ids': input_ids, 'attention_mask': attention_mask, 'label': labels}
    
#shuffle=True: Mỗi khi một epoch mới bắt đầu, các mẫu trong tập dữ liệu huấn luyện sẽ được trộn ngẫu nhiên
# Tạo DataLoader với collate_fn
train_dataloader = DataLoader(
    train_dataset,
    batch_size=12,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    collate_fn=collate_fn
)

val_dataloader = DataLoader(
    val_dataset,
    batch_size=12,
    num_workers=4,
    pin_memory=True,
    collate_fn=collate_fn
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Số lượng mẫu train: từ 24127 mẫu đã tăng lên 24127 mẫu
#
# Số lượng mẫu val: từ 5170 mẫu đã tăng lên 5170 mẫu

# %%
# --------------------- 5. Huấn luyện mô hình ---------------------

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CustomELECTRAModel(model_name).to(device)

trainer = ClassifierTrainer(
    model=model,
    train_dataloader=train_dataloader,
    val_dataloader=val_dataloader,
    device=device,
    lr=2e-5,
    epochs=12,
    accumulation_steps=4
)

trainer.train()  # Huấn luyện mô hình
# Out:
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Epoch 1: Training...
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Progress: 1% | Loss: 0.7229 | Accuracy: 0.5040
# Progress: 2% | Loss: 0.7078 | Accuracy: 0.5264
# Progress: 3% | Loss: 0.6978 | Accuracy: 0.5437
# Progress: 4% | Loss: 0.6951 | Accuracy: 0.5566
# Progress: 5% | Loss: 0.6879 | Accuracy: 0.5652
# Progress: 6% | Loss: 0.6811 | Accuracy: 0.5716
# Progress: 7% | Loss: 0.6767 | Accuracy: 0.5762
# Progress: 8% | Loss: 0.6714 | Accuracy: 0.5833
# Progress: 9% | Loss: 0.6641 | Accuracy: 0.5930
# Progress: 10% | Loss: 0.6552 | Accuracy: 0.6023
# Progress: 11% | Loss: 0.6464 | Accuracy: 0.6122
# Progress: 12% | Loss: 0.6436 | Accuracy: 0.6167
# Progress: 13% | Loss: 0.6315 | Accuracy: 0.6282
# Progress: 14% | Loss: 0.6209 | Accuracy: 0.6383
# Progress: 15% | Loss: 0.6144 | Accuracy: 0.6465
# Progress: 16% | Loss: 0.6079 | Accuracy: 0.6537
# Progress: 17% | Loss: 0.6011 | Accuracy: 0.6601
# Progress: 18% | Loss: 0.5984 | Accuracy: 0.6632
# Progress: 19% | Loss: 0.5918 | Accuracy: 0.6693
# Progress: 20% | Loss: 0.5887 | Accuracy: 0.6729
# Progress: 21% | Loss: 0.5811 | Accuracy: 0.6795
# Progress: 22% | Loss: 0.5765 | Accuracy: 0.6832
# Progress: 23% | Loss: 0.5721 | Accuracy: 0.6868
# Progress: 24% | Loss: 0.5653 | Accuracy: 0.6927
# Progress: 25% | Loss: 0.5585 | Accuracy: 0.6986
# Progress: 26% | Loss: 0.5510 | Accuracy: 0.7035
# Progress: 27% | Loss: 0.5500 | Accuracy: 0.7046
# Progress: 28% | Loss: 0.5496 | Accuracy: 0.7058
# Progress: 29% | Loss: 0.5465 | Accuracy: 0.7090
# Progress: 30% | Loss: 0.5438 | Accuracy: 0.7119
# Progress: 31% | Loss: 0.5386 | Accuracy: 0.7161
# Progress: 32% | Loss: 0.5344 | Accuracy: 0.7196
# Progress: 33% | Loss: 0.5327 | Accuracy: 0.7220
# Progress: 34% | Loss: 0.5290 | Accuracy: 0.7247
# Progress: 35% | Loss: 0.5266 | Accuracy: 0.7263
# Progress: 36% | Loss: 0.5242 | Accuracy: 0.7279
# Progress: 37% | Loss: 0.5224 | Accuracy: 0.7293
# Progress: 38% | Loss: 0.5190 | Accuracy: 0.7316
# Progress: 39% | Loss: 0.5184 | Accuracy: 0.7323
# Progress: 40% | Loss: 0.5153 | Accuracy: 0.7344
# Progress: 41% | Loss: 0.5132 | Accuracy: 0.7357
# Progress: 42% | Loss: 0.5106 | Accuracy: 0.7378
# Progress: 43% | Loss: 0.5090 | Accuracy: 0.7392
# Progress: 44% | Loss: 0.5085 | Accuracy: 0.7395
# Progress: 45% | Loss: 0.5064 | Accuracy: 0.7413
# Progress: 46% | Loss: 0.5054 | Accuracy: 0.7420
# Progress: 47% | Loss: 0.5027 | Accuracy: 0.7441
# Progress: 48% | Loss: 0.5011 | Accuracy: 0.7459
# Progress: 49% | Loss: 0.4994 | Accuracy: 0.7470
# Progress: 50% | Loss: 0.4968 | Accuracy: 0.7486
# Progress: 51% | Loss: 0.4936 | Accuracy: 0.7505
# Progress: 52% | Loss: 0.4918 | Accuracy: 0.7518
# Progress: 53% | Loss: 0.4900 | Accuracy: 0.7530
# Progress: 54% | Loss: 0.4882 | Accuracy: 0.7538
# Progress: 55% | Loss: 0.4868 | Accuracy: 0.7550
# Progress: 56% | Loss: 0.4851 | Accuracy: 0.7563
# Progress: 57% | Loss: 0.4832 | Accuracy: 0.7578
# Progress: 58% | Loss: 0.4811 | Accuracy: 0.7589
# Progress: 59% | Loss: 0.4803 | Accuracy: 0.7593
# Progress: 60% | Loss: 0.4793 | Accuracy: 0.7592
# Progress: 61% | Loss: 0.4784 | Accuracy: 0.7598
# Progress: 62% | Loss: 0.4773 | Accuracy: 0.7604
# Progress: 63% | Loss: 0.4756 | Accuracy: 0.7615
# Progress: 64% | Loss: 0.4741 | Accuracy: 0.7626
# Progress: 65% | Loss: 0.4731 | Accuracy: 0.7639
# Progress: 66% | Loss: 0.4720 | Accuracy: 0.7647
# Progress: 67% | Loss: 0.4708 | Accuracy: 0.7655
# Progress: 68% | Loss: 0.4691 | Accuracy: 0.7666
# Progress: 69% | Loss: 0.4675 | Accuracy: 0.7675
# Progress: 70% | Loss: 0.4662 | Accuracy: 0.7681
# Progress: 71% | Loss: 0.4642 | Accuracy: 0.7692
# Progress: 72% | Loss: 0.4625 | Accuracy: 0.7700
# Progress: 73% | Loss: 0.4604 | Accuracy: 0.7713
# Progress: 74% | Loss: 0.4595 | Accuracy: 0.7721
# Progress: 75% | Loss: 0.4586 | Accuracy: 0.7728
# Progress: 76% | Loss: 0.4572 | Accuracy: 0.7738
# Progress: 77% | Loss: 0.4566 | Accuracy: 0.7744
# Progress: 78% | Loss: 0.4562 | Accuracy: 0.7749
# Progress: 79% | Loss: 0.4547 | Accuracy: 0.7759
# Progress: 80% | Loss: 0.4530 | Accuracy: 0.7770
# Progress: 81% | Loss: 0.4522 | Accuracy: 0.7779
# Progress: 82% | Loss: 0.4506 | Accuracy: 0.7789
# Progress: 83% | Loss: 0.4492 | Accuracy: 0.7799
# Progress: 84% | Loss: 0.4488 | Accuracy: 0.7803
# Progress: 85% | Loss: 0.4482 | Accuracy: 0.7809
# Progress: 86% | Loss: 0.4471 | Accuracy: 0.7815
# Progress: 87% | Loss: 0.4463 | Accuracy: 0.7820
# Progress: 88% | Loss: 0.4455 | Accuracy: 0.7827
# Progress: 89% | Loss: 0.4444 | Accuracy: 0.7837
# Progress: 90% | Loss: 0.4440 | Accuracy: 0.7840
# Progress: 91% | Loss: 0.4432 | Accuracy: 0.7845
# Progress: 92% | Loss: 0.4419 | Accuracy: 0.7855
# Progress: 93% | Loss: 0.4408 | Accuracy: 0.7862
# Progress: 94% | Loss: 0.4397 | Accuracy: 0.7870
# Progress: 95% | Loss: 0.4385 | Accuracy: 0.7878
# Progress: 96% | Loss: 0.4377 | Accuracy: 0.7882
# Progress: 97% | Loss: 0.4373 | Accuracy: 0.7881
# Progress: 98% | Loss: 0.4366 | Accuracy: 0.7886
# Progress: 99% | Loss: 0.4362 | Accuracy: 0.7887
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Progress: 100% | Loss: 0.4355 | Accuracy: 0.7892
#   Training completed in 316.07 seconds.
# Epoch 1: Evaluating (Validation)...
# Progress: 1% | Loss: 0.3910 | Accuracy: 0.8000
# Progress: 2% | Loss: 0.3392 | Accuracy: 0.8611
# Progress: 3% | Loss: 0.3774 | Accuracy: 0.8397
# Progress: 4% | Loss: 0.3726 | Accuracy: 0.8333
# Progress: 5% | Loss: 0.3605 | Accuracy: 0.8409
# Progress: 6% | Loss: 0.3561 | Accuracy: 0.8429
# Progress: 7% | Loss: 0.3662 | Accuracy: 0.8387
# Progress: 8% | Loss: 0.3822 | Accuracy: 0.8262
# Progress: 9% | Loss: 0.3623 | Accuracy: 0.8355
# Progress: 10% | Loss: 0.3571 | Accuracy: 0.8409
# Progress: 11% | Loss: 0.3614 | Accuracy: 0.8368
# Progress: 12% | Loss: 0.3653 | Accuracy: 0.8317
# Progress: 13% | Loss: 0.3709 | Accuracy: 0.8260
# Progress: 14% | Loss: 0.3661 | Accuracy: 0.8265
# Progress: 15% | Loss: 0.3707 | Accuracy: 0.8218
# Progress: 16% | Loss: 0.3698 | Accuracy: 0.8237
# Progress: 17% | Loss: 0.3656 | Accuracy: 0.8243
# Progress: 18% | Loss: 0.3704 | Accuracy: 0.8194
# Progress: 19% | Loss: 0.3694 | Accuracy: 0.8201
# Progress: 20% | Loss: 0.3661 | Accuracy: 0.8238
# Progress: 21% | Loss: 0.3692 | Accuracy: 0.8214
# Progress: 22% | Loss: 0.3656 | Accuracy: 0.8237
# Progress: 23% | Loss: 0.3646 | Accuracy: 0.8225
# Progress: 24% | Loss: 0.3627 | Accuracy: 0.8229
# Progress: 25% | Loss: 0.3643 | Accuracy: 0.8225
# Progress: 26% | Loss: 0.3683 | Accuracy: 0.8201
# Progress: 27% | Loss: 0.3690 | Accuracy: 0.8205
# Progress: 28% | Loss: 0.3686 | Accuracy: 0.8216
# Progress: 29% | Loss: 0.3692 | Accuracy: 0.8200
# Progress: 30% | Loss: 0.3621 | Accuracy: 0.8250
# Progress: 31% | Loss: 0.3653 | Accuracy: 0.8228
# Progress: 32% | Loss: 0.3647 | Accuracy: 0.8237
# Progress: 33% | Loss: 0.3657 | Accuracy: 0.8223
# Progress: 34% | Loss: 0.3665 | Accuracy: 0.8214
# Progress: 35% | Loss: 0.3645 | Accuracy: 0.8223
# Progress: 36% | Loss: 0.3620 | Accuracy: 0.8248
# Progress: 37% | Loss: 0.3627 | Accuracy: 0.8245
# Progress: 38% | Loss: 0.3638 | Accuracy: 0.8232
# Progress: 39% | Loss: 0.3630 | Accuracy: 0.8225
# Progress: 40% | Loss: 0.3608 | Accuracy: 0.8237
# Progress: 41% | Loss: 0.3626 | Accuracy: 0.8225
# Progress: 42% | Loss: 0.3621 | Accuracy: 0.8233
# Progress: 43% | Loss: 0.3615 | Accuracy: 0.8226
# Progress: 44% | Loss: 0.3584 | Accuracy: 0.8246
# Progress: 45% | Loss: 0.3604 | Accuracy: 0.8235
# Progress: 46% | Loss: 0.3594 | Accuracy: 0.8237
# Progress: 47% | Loss: 0.3601 | Accuracy: 0.8235
# Progress: 48% | Loss: 0.3586 | Accuracy: 0.8241
# Progress: 49% | Loss: 0.3571 | Accuracy: 0.8251
# Progress: 50% | Loss: 0.3573 | Accuracy: 0.8248
# Progress: 51% | Loss: 0.3589 | Accuracy: 0.8227
# Progress: 52% | Loss: 0.3595 | Accuracy: 0.8222
# Progress: 53% | Loss: 0.3595 | Accuracy: 0.8224
# Progress: 54% | Loss: 0.3584 | Accuracy: 0.8230
# Progress: 55% | Loss: 0.3584 | Accuracy: 0.8232
# Progress: 56% | Loss: 0.3571 | Accuracy: 0.8240
# Progress: 57% | Loss: 0.3571 | Accuracy: 0.8245
# Progress: 58% | Loss: 0.3561 | Accuracy: 0.8257
# Progress: 59% | Loss: 0.3564 | Accuracy: 0.8252
# Progress: 60% | Loss: 0.3553 | Accuracy: 0.8256
# Progress: 61% | Loss: 0.3559 | Accuracy: 0.8251
# Progress: 62% | Loss: 0.3554 | Accuracy: 0.8256
# Progress: 63% | Loss: 0.3545 | Accuracy: 0.8257
# Progress: 64% | Loss: 0.3543 | Accuracy: 0.8258
# Progress: 65% | Loss: 0.3543 | Accuracy: 0.8256
# Progress: 66% | Loss: 0.3539 | Accuracy: 0.8254
# Progress: 67% | Loss: 0.3541 | Accuracy: 0.8250
# Progress: 68% | Loss: 0.3540 | Accuracy: 0.8245
# Progress: 69% | Loss: 0.3551 | Accuracy: 0.8241
# Progress: 70% | Loss: 0.3579 | Accuracy: 0.8223
# Progress: 71% | Loss: 0.3583 | Accuracy: 0.8222
# Progress: 72% | Loss: 0.3574 | Accuracy: 0.8232
# Progress: 73% | Loss: 0.3593 | Accuracy: 0.8220
# Progress: 74% | Loss: 0.3588 | Accuracy: 0.8221
# Progress: 75% | Loss: 0.3575 | Accuracy: 0.8230
# Progress: 76% | Loss: 0.3577 | Accuracy: 0.8227
# Progress: 77% | Loss: 0.3579 | Accuracy: 0.8223
# Progress: 78% | Loss: 0.3587 | Accuracy: 0.8215
# Progress: 79% | Loss: 0.3582 | Accuracy: 0.8218
# Progress: 80% | Loss: 0.3576 | Accuracy: 0.8227
# Progress: 81% | Loss: 0.3565 | Accuracy: 0.8236
# Progress: 82% | Loss: 0.3565 | Accuracy: 0.8234
# Progress: 83% | Loss: 0.3570 | Accuracy: 0.8229
# Progress: 84% | Loss: 0.3561 | Accuracy: 0.8235
# Progress: 85% | Loss: 0.3573 | Accuracy: 0.8227
# Progress: 86% | Loss: 0.3573 | Accuracy: 0.8226
# Progress: 87% | Loss: 0.3565 | Accuracy: 0.8229
# Progress: 88% | Loss: 0.3559 | Accuracy: 0.8230
# Progress: 89% | Loss: 0.3554 | Accuracy: 0.8236
# Progress: 90% | Loss: 0.3542 | Accuracy: 0.8245
# Progress: 91% | Loss: 0.3535 | Accuracy: 0.8253
# Progress: 92% | Loss: 0.3545 | Accuracy: 0.8243
# Progress: 93% | Loss: 0.3561 | Accuracy: 0.8236
# Progress: 94% | Loss: 0.3561 | Accuracy: 0.8233
# Progress: 95% | Loss: 0.3551 | Accuracy: 0.8236
# Progress: 96% | Loss: 0.3548 | Accuracy: 0.8235
# Progress: 97% | Loss: 0.3558 | Accuracy: 0.8230
# Progress: 98% | Loss: 0.3550 | Accuracy: 0.8233
# Progress: 99% | Loss: 0.3556 | Accuracy: 0.8226
# Progress: 100% | Loss: 0.3549 | Accuracy: 0.8229
#   Validation completed in 23.69 seconds.
# Epoch 1/12:
#   Train Loss: 0.4355 | Train Accuracy: 0.7894
#   Val Loss: 0.3549 | Val Accuracy: 0.8232
#   Saved best model to /kaggle/working/best_model_epoch_1_val_acc_0.8232.pth
# Epoch 2: Training...
# Progress: 1% | Loss: 0.4168 | Accuracy: 0.7857
# Progress: 2% | Loss: 0.3913 | Accuracy: 0.8293
# Progress: 3% | Loss: 0.3549 | Accuracy: 0.8470
# Progress: 4% | Loss: 0.3296 | Accuracy: 0.8580
# Progress: 5% | Loss: 0.3267 | Accuracy: 0.8589
# Progress: 6% | Loss: 0.3244 | Accuracy: 0.8609
# Progress: 7% | Loss: 0.3200 | Accuracy: 0.8641
# Progress: 8% | Loss: 0.3201 | Accuracy: 0.8628
# Progress: 9% | Loss: 0.3131 | Accuracy: 0.8660
# Progress: 10% | Loss: 0.3124 | Accuracy: 0.8651
# Progress: 11% | Loss: 0.3099 | Accuracy: 0.8652
# Progress: 12% | Loss: 0.3099 | Accuracy: 0.8629
# Progress: 13% | Loss: 0.3085 | Accuracy: 0.8635
# Progress: 14% | Loss: 0.3070 | Accuracy: 0.8632
# Progress: 15% | Loss: 0.3059 | Accuracy: 0.8623
# Progress: 16% | Loss: 0.3060 | Accuracy: 0.8623
# Progress: 17% | Loss: 0.3051 | Accuracy: 0.8643
# Progress: 18% | Loss: 0.3015 | Accuracy: 0.8656
# Progress: 19% | Loss: 0.3044 | Accuracy: 0.8644
# Progress: 20% | Loss: 0.3018 | Accuracy: 0.8656
# Progress: 21% | Loss: 0.3039 | Accuracy: 0.8649
# Progress: 22% | Loss: 0.3030 | Accuracy: 0.8649
# Progress: 23% | Loss: 0.3007 | Accuracy: 0.8657
# Progress: 24% | Loss: 0.3006 | Accuracy: 0.8654
# Progress: 25% | Loss: 0.2992 | Accuracy: 0.8660
# Progress: 26% | Loss: 0.2977 | Accuracy: 0.8662
# Progress: 27% | Loss: 0.2974 | Accuracy: 0.8666
# Progress: 28% | Loss: 0.2958 | Accuracy: 0.8670
# Progress: 29% | Loss: 0.2942 | Accuracy: 0.8670
# Progress: 30% | Loss: 0.2939 | Accuracy: 0.8669
# Progress: 31% | Loss: 0.2936 | Accuracy: 0.8666
# Progress: 32% | Loss: 0.2934 | Accuracy: 0.8663
# Progress: 33% | Loss: 0.2937 | Accuracy: 0.8665
# Progress: 34% | Loss: 0.2923 | Accuracy: 0.8671
# Progress: 35% | Loss: 0.2919 | Accuracy: 0.8677
# Progress: 36% | Loss: 0.2898 | Accuracy: 0.8688
# Progress: 37% | Loss: 0.2914 | Accuracy: 0.8681
# Progress: 38% | Loss: 0.2920 | Accuracy: 0.8681
# Progress: 39% | Loss: 0.2923 | Accuracy: 0.8675
# Progress: 40% | Loss: 0.2918 | Accuracy: 0.8677
# Progress: 41% | Loss: 0.2927 | Accuracy: 0.8679
# Progress: 42% | Loss: 0.2927 | Accuracy: 0.8675
# Progress: 43% | Loss: 0.2919 | Accuracy: 0.8681
# Progress: 44% | Loss: 0.2914 | Accuracy: 0.8687
# Progress: 45% | Loss: 0.2905 | Accuracy: 0.8692
# Progress: 46% | Loss: 0.2898 | Accuracy: 0.8695
# Progress: 47% | Loss: 0.2887 | Accuracy: 0.8702
# Progress: 48% | Loss: 0.2879 | Accuracy: 0.8707
# Progress: 49% | Loss: 0.2874 | Accuracy: 0.8710
# Progress: 50% | Loss: 0.2863 | Accuracy: 0.8719
# Progress: 51% | Loss: 0.2858 | Accuracy: 0.8723
# Progress: 52% | Loss: 0.2860 | Accuracy: 0.8722
# Progress: 53% | Loss: 0.2857 | Accuracy: 0.8721
# Progress: 54% | Loss: 0.2859 | Accuracy: 0.8723
# Progress: 55% | Loss: 0.2847 | Accuracy: 0.8732
# Progress: 56% | Loss: 0.2840 | Accuracy: 0.8736
# Progress: 57% | Loss: 0.2839 | Accuracy: 0.8736
# Progress: 58% | Loss: 0.2835 | Accuracy: 0.8733
# Progress: 59% | Loss: 0.2831 | Accuracy: 0.8736
# Progress: 60% | Loss: 0.2832 | Accuracy: 0.8734
# Progress: 61% | Loss: 0.2830 | Accuracy: 0.8735
# Progress: 62% | Loss: 0.2825 | Accuracy: 0.8738
# Progress: 63% | Loss: 0.2821 | Accuracy: 0.8738
# Progress: 64% | Loss: 0.2827 | Accuracy: 0.8736
# Progress: 65% | Loss: 0.2825 | Accuracy: 0.8735
# Progress: 66% | Loss: 0.2820 | Accuracy: 0.8740
# Progress: 67% | Loss: 0.2814 | Accuracy: 0.8745
# Progress: 68% | Loss: 0.2808 | Accuracy: 0.8745
# Progress: 69% | Loss: 0.2801 | Accuracy: 0.8751
# Progress: 70% | Loss: 0.2794 | Accuracy: 0.8755
# Progress: 71% | Loss: 0.2791 | Accuracy: 0.8758
# Progress: 72% | Loss: 0.2780 | Accuracy: 0.8762
# Progress: 73% | Loss: 0.2777 | Accuracy: 0.8767
# Progress: 74% | Loss: 0.2776 | Accuracy: 0.8765
# Progress: 75% | Loss: 0.2767 | Accuracy: 0.8770
# Progress: 76% | Loss: 0.2763 | Accuracy: 0.8770
# Progress: 77% | Loss: 0.2756 | Accuracy: 0.8771
# Progress: 78% | Loss: 0.2752 | Accuracy: 0.8773
# Progress: 79% | Loss: 0.2752 | Accuracy: 0.8775
# Progress: 80% | Loss: 0.2750 | Accuracy: 0.8774
# Progress: 81% | Loss: 0.2752 | Accuracy: 0.8777
# Progress: 82% | Loss: 0.2754 | Accuracy: 0.8773
# Progress: 83% | Loss: 0.2750 | Accuracy: 0.8773
# Progress: 84% | Loss: 0.2744 | Accuracy: 0.8779
# Progress: 85% | Loss: 0.2745 | Accuracy: 0.8778
# Progress: 86% | Loss: 0.2742 | Accuracy: 0.8779
# Progress: 87% | Loss: 0.2736 | Accuracy: 0.8782
# Progress: 88% | Loss: 0.2743 | Accuracy: 0.8781
# Progress: 89% | Loss: 0.2737 | Accuracy: 0.8786
# Progress: 90% | Loss: 0.2741 | Accuracy: 0.8784
# Progress: 91% | Loss: 0.2738 | Accuracy: 0.8783
# Progress: 92% | Loss: 0.2739 | Accuracy: 0.8781
# Progress: 93% | Loss: 0.2733 | Accuracy: 0.8783
# Progress: 94% | Loss: 0.2735 | Accuracy: 0.8782
# Progress: 95% | Loss: 0.2735 | Accuracy: 0.8782
# Progress: 96% | Loss: 0.2732 | Accuracy: 0.8783
# Progress: 97% | Loss: 0.2728 | Accuracy: 0.8784
# Progress: 98% | Loss: 0.2728 | Accuracy: 0.8785
# Progress: 99% | Loss: 0.2729 | Accuracy: 0.8786
# Progress: 100% | Loss: 0.2725 | Accuracy: 0.8787
#   Training completed in 315.02 seconds.
# Epoch 2: Evaluating (Validation)...
# Progress: 1% | Loss: 0.3306 | Accuracy: 0.9000
# Progress: 2% | Loss: 0.2857 | Accuracy: 0.9074
# Progress: 3% | Loss: 0.3117 | Accuracy: 0.8910
# Progress: 4% | Loss: 0.2912 | Accuracy: 0.8935
# Progress: 5% | Loss: 0.2813 | Accuracy: 0.8977
# Progress: 6% | Loss: 0.2839 | Accuracy: 0.8942
# Progress: 7% | Loss: 0.2869 | Accuracy: 0.8978
# Progress: 8% | Loss: 0.3196 | Accuracy: 0.8810
# Progress: 9% | Loss: 0.2967 | Accuracy: 0.8910
# Progress: 10% | Loss: 0.2890 | Accuracy: 0.8902
# Progress: 11% | Loss: 0.2872 | Accuracy: 0.8889
# Progress: 12% | Loss: 0.2888 | Accuracy: 0.8878
# Progress: 13% | Loss: 0.3023 | Accuracy: 0.8860
# Progress: 14% | Loss: 0.2972 | Accuracy: 0.8866
# Progress: 15% | Loss: 0.3018 | Accuracy: 0.8833
# Progress: 16% | Loss: 0.2985 | Accuracy: 0.8853
# Progress: 17% | Loss: 0.2907 | Accuracy: 0.8851
# Progress: 18% | Loss: 0.2891 | Accuracy: 0.8846
# Progress: 19% | Loss: 0.2908 | Accuracy: 0.8841
# Progress: 20% | Loss: 0.2879 | Accuracy: 0.8841
# Progress: 21% | Loss: 0.2951 | Accuracy: 0.8837
# Progress: 22% | Loss: 0.2877 | Accuracy: 0.8860
# Progress: 23% | Loss: 0.2858 | Accuracy: 0.8850
# Progress: 24% | Loss: 0.2796 | Accuracy: 0.8878
# Progress: 25% | Loss: 0.2895 | Accuracy: 0.8850
# Progress: 26% | Loss: 0.2973 | Accuracy: 0.8813
# Progress: 27% | Loss: 0.2987 | Accuracy: 0.8811
# Progress: 28% | Loss: 0.2994 | Accuracy: 0.8809
# Progress: 29% | Loss: 0.3035 | Accuracy: 0.8793
# Progress: 30% | Loss: 0.2947 | Accuracy: 0.8827
# Progress: 31% | Loss: 0.3007 | Accuracy: 0.8794
# Progress: 32% | Loss: 0.3013 | Accuracy: 0.8786
# Progress: 33% | Loss: 0.3050 | Accuracy: 0.8782
# Progress: 34% | Loss: 0.3058 | Accuracy: 0.8770
# Progress: 35% | Loss: 0.3045 | Accuracy: 0.8775
# Progress: 36% | Loss: 0.3013 | Accuracy: 0.8798
# Progress: 37% | Loss: 0.3077 | Accuracy: 0.8781
# Progress: 38% | Loss: 0.3093 | Accuracy: 0.8770
# Progress: 39% | Loss: 0.3057 | Accuracy: 0.8782
# Progress: 40% | Loss: 0.3026 | Accuracy: 0.8796
# Progress: 41% | Loss: 0.3031 | Accuracy: 0.8785
# Progress: 42% | Loss: 0.3041 | Accuracy: 0.8782
# Progress: 43% | Loss: 0.3035 | Accuracy: 0.8777
# Progress: 44% | Loss: 0.3004 | Accuracy: 0.8789
# Progress: 45% | Loss: 0.3028 | Accuracy: 0.8776
# Progress: 46% | Loss: 0.3007 | Accuracy: 0.8781
# Progress: 47% | Loss: 0.3000 | Accuracy: 0.8781
# Progress: 48% | Loss: 0.2978 | Accuracy: 0.8784
# Progress: 49% | Loss: 0.2946 | Accuracy: 0.8797
# Progress: 50% | Loss: 0.2938 | Accuracy: 0.8796
# Progress: 51% | Loss: 0.2939 | Accuracy: 0.8795
# Progress: 52% | Loss: 0.2953 | Accuracy: 0.8789
# Progress: 53% | Loss: 0.2939 | Accuracy: 0.8795
# Progress: 54% | Loss: 0.2923 | Accuracy: 0.8802
# Progress: 55% | Loss: 0.2913 | Accuracy: 0.8796
# Progress: 56% | Loss: 0.2909 | Accuracy: 0.8798
# Progress: 57% | Loss: 0.2916 | Accuracy: 0.8797
# Progress: 58% | Loss: 0.2908 | Accuracy: 0.8803
# Progress: 59% | Loss: 0.2910 | Accuracy: 0.8801
# Progress: 60% | Loss: 0.2902 | Accuracy: 0.8800
# Progress: 61% | Loss: 0.2919 | Accuracy: 0.8790
# Progress: 62% | Loss: 0.2910 | Accuracy: 0.8794
# Progress: 63% | Loss: 0.2890 | Accuracy: 0.8802
# Progress: 64% | Loss: 0.2869 | Accuracy: 0.8807
# Progress: 65% | Loss: 0.2865 | Accuracy: 0.8805
# Progress: 66% | Loss: 0.2843 | Accuracy: 0.8813
# Progress: 67% | Loss: 0.2843 | Accuracy: 0.8812
# Progress: 68% | Loss: 0.2847 | Accuracy: 0.8801
# Progress: 69% | Loss: 0.2863 | Accuracy: 0.8798
# Progress: 70% | Loss: 0.2883 | Accuracy: 0.8791
# Progress: 71% | Loss: 0.2903 | Accuracy: 0.8789
# Progress: 72% | Loss: 0.2887 | Accuracy: 0.8794
# Progress: 73% | Loss: 0.2909 | Accuracy: 0.8783
# Progress: 74% | Loss: 0.2918 | Accuracy: 0.8780
# Progress: 75% | Loss: 0.2909 | Accuracy: 0.8783
# Progress: 76% | Loss: 0.2922 | Accuracy: 0.8780
# Progress: 77% | Loss: 0.2922 | Accuracy: 0.8783
# Progress: 78% | Loss: 0.2932 | Accuracy: 0.8786
# Progress: 79% | Loss: 0.2918 | Accuracy: 0.8795
# Progress: 80% | Loss: 0.2913 | Accuracy: 0.8797
# Progress: 81% | Loss: 0.2906 | Accuracy: 0.8800
# Progress: 82% | Loss: 0.2901 | Accuracy: 0.8804
# Progress: 83% | Loss: 0.2898 | Accuracy: 0.8806
# Progress: 84% | Loss: 0.2888 | Accuracy: 0.8806
# Progress: 85% | Loss: 0.2899 | Accuracy: 0.8803
# Progress: 86% | Loss: 0.2897 | Accuracy: 0.8803
# Progress: 87% | Loss: 0.2885 | Accuracy: 0.8809
# Progress: 88% | Loss: 0.2872 | Accuracy: 0.8816
# Progress: 89% | Loss: 0.2857 | Accuracy: 0.8824
# Progress: 90% | Loss: 0.2846 | Accuracy: 0.8825
# Progress: 91% | Loss: 0.2840 | Accuracy: 0.8832
# Progress: 92% | Loss: 0.2849 | Accuracy: 0.8831
# Progress: 93% | Loss: 0.2865 | Accuracy: 0.8828
# Progress: 94% | Loss: 0.2859 | Accuracy: 0.8832
# Progress: 95% | Loss: 0.2851 | Accuracy: 0.8837
# Progress: 96% | Loss: 0.2853 | Accuracy: 0.8837
# Progress: 97% | Loss: 0.2871 | Accuracy: 0.8833
# Progress: 98% | Loss: 0.2856 | Accuracy: 0.8838
# Progress: 99% | Loss: 0.2858 | Accuracy: 0.8837
# Progress: 100% | Loss: 0.2854 | Accuracy: 0.8832
#   Validation completed in 23.70 seconds.
# Epoch 2/12:
#   Train Loss: 0.2725 | Train Accuracy: 0.8789
#   Val Loss: 0.2854 | Val Accuracy: 0.8836
#   Saved best model to /kaggle/working/best_model_epoch_2_val_acc_0.8836.pth
# Epoch 3: Training...
# Progress: 1% | Loss: 0.2128 | Accuracy: 0.9048
# Progress: 2% | Loss: 0.2089 | Accuracy: 0.9024
# Progress: 3% | Loss: 0.1916 | Accuracy: 0.9167
# Progress: 4% | Loss: 0.1964 | Accuracy: 0.9167
# Progress: 5% | Loss: 0.1893 | Accuracy: 0.9216
# Progress: 6% | Loss: 0.1876 | Accuracy: 0.9201
# Progress: 7% | Loss: 0.1883 | Accuracy: 0.9214
# Progress: 8% | Loss: 0.1886 | Accuracy: 0.9203
# Progress: 9% | Loss: 0.1849 | Accuracy: 0.9231
# Progress: 10% | Loss: 0.1840 | Accuracy: 0.9229
# Progress: 11% | Loss: 0.1864 | Accuracy: 0.9223
# Progress: 12% | Loss: 0.1859 | Accuracy: 0.9222
# Progress: 13% | Loss: 0.1856 | Accuracy: 0.9218
# Progress: 14% | Loss: 0.1850 | Accuracy: 0.9220
# Progress: 15% | Loss: 0.1855 | Accuracy: 0.9230
# Progress: 16% | Loss: 0.1819 | Accuracy: 0.9252
# Progress: 17% | Loss: 0.1857 | Accuracy: 0.9228
# Progress: 18% | Loss: 0.1841 | Accuracy: 0.9236
# Progress: 19% | Loss: 0.1867 | Accuracy: 0.9230
# Progress: 20% | Loss: 0.1879 | Accuracy: 0.9222
# Progress: 21% | Loss: 0.1869 | Accuracy: 0.9232
# Progress: 22% | Loss: 0.1856 | Accuracy: 0.9242
# Progress: 23% | Loss: 0.1841 | Accuracy: 0.9242
# Progress: 24% | Loss: 0.1851 | Accuracy: 0.9227
# Progress: 25% | Loss: 0.1871 | Accuracy: 0.9221
# Progress: 26% | Loss: 0.1883 | Accuracy: 0.9210
# Progress: 27% | Loss: 0.1897 | Accuracy: 0.9199
# Progress: 28% | Loss: 0.1913 | Accuracy: 0.9190
# Progress: 29% | Loss: 0.1905 | Accuracy: 0.9197
# Progress: 30% | Loss: 0.1897 | Accuracy: 0.9203
# Progress: 31% | Loss: 0.1920 | Accuracy: 0.9197
# Progress: 32% | Loss: 0.1923 | Accuracy: 0.9198
# Progress: 33% | Loss: 0.1902 | Accuracy: 0.9211
# Progress: 34% | Loss: 0.1886 | Accuracy: 0.9218
# Progress: 35% | Loss: 0.1892 | Accuracy: 0.9219
# Progress: 36% | Loss: 0.1881 | Accuracy: 0.9223
# Progress: 37% | Loss: 0.1882 | Accuracy: 0.9223
# Progress: 38% | Loss: 0.1864 | Accuracy: 0.9227
# Progress: 39% | Loss: 0.1855 | Accuracy: 0.9230
# Progress: 40% | Loss: 0.1849 | Accuracy: 0.9234
# Progress: 41% | Loss: 0.1855 | Accuracy: 0.9228
# Progress: 42% | Loss: 0.1846 | Accuracy: 0.9233
# Progress: 43% | Loss: 0.1830 | Accuracy: 0.9238
# Progress: 44% | Loss: 0.1829 | Accuracy: 0.9243
# Progress: 45% | Loss: 0.1820 | Accuracy: 0.9250
# Progress: 46% | Loss: 0.1814 | Accuracy: 0.9254
# Progress: 47% | Loss: 0.1808 | Accuracy: 0.9255
# Progress: 48% | Loss: 0.1814 | Accuracy: 0.9254
# Progress: 49% | Loss: 0.1807 | Accuracy: 0.9258
# Progress: 50% | Loss: 0.1811 | Accuracy: 0.9255
# Progress: 51% | Loss: 0.1826 | Accuracy: 0.9254
# Progress: 52% | Loss: 0.1831 | Accuracy: 0.9250
# Progress: 53% | Loss: 0.1834 | Accuracy: 0.9249
# Progress: 54% | Loss: 0.1827 | Accuracy: 0.9254
# Progress: 55% | Loss: 0.1827 | Accuracy: 0.9253
# Progress: 56% | Loss: 0.1828 | Accuracy: 0.9256
# Progress: 57% | Loss: 0.1825 | Accuracy: 0.9257
# Progress: 58% | Loss: 0.1827 | Accuracy: 0.9259
# Progress: 59% | Loss: 0.1828 | Accuracy: 0.9257
# Progress: 60% | Loss: 0.1820 | Accuracy: 0.9258
# Progress: 61% | Loss: 0.1809 | Accuracy: 0.9263
# Progress: 62% | Loss: 0.1806 | Accuracy: 0.9268
# Progress: 63% | Loss: 0.1808 | Accuracy: 0.9267
# Progress: 64% | Loss: 0.1806 | Accuracy: 0.9270
# Progress: 65% | Loss: 0.1800 | Accuracy: 0.9272
# Progress: 66% | Loss: 0.1797 | Accuracy: 0.9274
# Progress: 67% | Loss: 0.1799 | Accuracy: 0.9272
# Progress: 68% | Loss: 0.1796 | Accuracy: 0.9272
# Progress: 69% | Loss: 0.1803 | Accuracy: 0.9270
# Progress: 70% | Loss: 0.1814 | Accuracy: 0.9263
# Progress: 71% | Loss: 0.1818 | Accuracy: 0.9260
# Progress: 72% | Loss: 0.1820 | Accuracy: 0.9256
# Progress: 73% | Loss: 0.1821 | Accuracy: 0.9256
# Progress: 74% | Loss: 0.1818 | Accuracy: 0.9259
# Progress: 75% | Loss: 0.1813 | Accuracy: 0.9262
# Progress: 76% | Loss: 0.1813 | Accuracy: 0.9263
# Progress: 77% | Loss: 0.1809 | Accuracy: 0.9265
# Progress: 78% | Loss: 0.1804 | Accuracy: 0.9267
# Progress: 79% | Loss: 0.1802 | Accuracy: 0.9266
# Progress: 80% | Loss: 0.1796 | Accuracy: 0.9267
# Progress: 81% | Loss: 0.1796 | Accuracy: 0.9268
# Progress: 82% | Loss: 0.1791 | Accuracy: 0.9270
# Progress: 83% | Loss: 0.1793 | Accuracy: 0.9268
# Progress: 84% | Loss: 0.1791 | Accuracy: 0.9270
# Progress: 85% | Loss: 0.1796 | Accuracy: 0.9267
# Progress: 86% | Loss: 0.1799 | Accuracy: 0.9265
# Progress: 87% | Loss: 0.1797 | Accuracy: 0.9267
# Progress: 88% | Loss: 0.1793 | Accuracy: 0.9268
# Progress: 89% | Loss: 0.1793 | Accuracy: 0.9268
# Progress: 90% | Loss: 0.1792 | Accuracy: 0.9267
# Progress: 91% | Loss: 0.1791 | Accuracy: 0.9268
# Progress: 92% | Loss: 0.1786 | Accuracy: 0.9269
# Progress: 93% | Loss: 0.1783 | Accuracy: 0.9270
# Progress: 94% | Loss: 0.1785 | Accuracy: 0.9271
# Progress: 95% | Loss: 0.1779 | Accuracy: 0.9273
# Progress: 96% | Loss: 0.1774 | Accuracy: 0.9276
# Progress: 97% | Loss: 0.1772 | Accuracy: 0.9277
# Progress: 98% | Loss: 0.1773 | Accuracy: 0.9278
# Progress: 99% | Loss: 0.1770 | Accuracy: 0.9281
# Progress: 100% | Loss: 0.1765 | Accuracy: 0.9280
#   Training completed in 315.04 seconds.
# Epoch 3: Evaluating (Validation)...
# Progress: 1% | Loss: 0.1378 | Accuracy: 0.9667
# Progress: 2% | Loss: 0.1543 | Accuracy: 0.9630
# Progress: 3% | Loss: 0.1511 | Accuracy: 0.9487
# Progress: 4% | Loss: 0.1398 | Accuracy: 0.9491
# Progress: 5% | Loss: 0.1284 | Accuracy: 0.9545
# Progress: 6% | Loss: 0.1268 | Accuracy: 0.9551
# Progress: 7% | Loss: 0.1276 | Accuracy: 0.9597
# Progress: 8% | Loss: 0.1333 | Accuracy: 0.9548
# Progress: 9% | Loss: 0.1267 | Accuracy: 0.9530
# Progress: 10% | Loss: 0.1365 | Accuracy: 0.9508
# Progress: 11% | Loss: 0.1403 | Accuracy: 0.9462
# Progress: 12% | Loss: 0.1391 | Accuracy: 0.9455
# Progress: 13% | Loss: 0.1653 | Accuracy: 0.9342
# Progress: 14% | Loss: 0.1648 | Accuracy: 0.9344
# Progress: 15% | Loss: 0.1644 | Accuracy: 0.9346
# Progress: 16% | Loss: 0.1610 | Accuracy: 0.9348
# Progress: 17% | Loss: 0.1533 | Accuracy: 0.9381
# Progress: 18% | Loss: 0.1571 | Accuracy: 0.9380
# Progress: 19% | Loss: 0.1583 | Accuracy: 0.9380
# Progress: 20% | Loss: 0.1651 | Accuracy: 0.9368
# Progress: 21% | Loss: 0.1639 | Accuracy: 0.9368
# Progress: 22% | Loss: 0.1590 | Accuracy: 0.9386
# Progress: 23% | Loss: 0.1534 | Accuracy: 0.9408
# Progress: 24% | Loss: 0.1525 | Accuracy: 0.9423
# Progress: 25% | Loss: 0.1613 | Accuracy: 0.9390
# Progress: 26% | Loss: 0.1588 | Accuracy: 0.9388
# Progress: 27% | Loss: 0.1586 | Accuracy: 0.9395
# Progress: 28% | Loss: 0.1650 | Accuracy: 0.9373
# Progress: 29% | Loss: 0.1664 | Accuracy: 0.9360
# Progress: 30% | Loss: 0.1619 | Accuracy: 0.9378
# Progress: 31% | Loss: 0.1680 | Accuracy: 0.9359
# Progress: 32% | Loss: 0.1688 | Accuracy: 0.9360
# Progress: 33% | Loss: 0.1706 | Accuracy: 0.9359
# Progress: 34% | Loss: 0.1694 | Accuracy: 0.9359
# Progress: 35% | Loss: 0.1688 | Accuracy: 0.9360
# Progress: 36% | Loss: 0.1704 | Accuracy: 0.9348
# Progress: 37% | Loss: 0.1756 | Accuracy: 0.9339
# Progress: 38% | Loss: 0.1755 | Accuracy: 0.9339
# Progress: 39% | Loss: 0.1757 | Accuracy: 0.9324
# Progress: 40% | Loss: 0.1731 | Accuracy: 0.9330
# Progress: 41% | Loss: 0.1745 | Accuracy: 0.9317
# Progress: 42% | Loss: 0.1783 | Accuracy: 0.9309
# Progress: 43% | Loss: 0.1762 | Accuracy: 0.9323
# Progress: 44% | Loss: 0.1744 | Accuracy: 0.9329
# Progress: 45% | Loss: 0.1726 | Accuracy: 0.9334
# Progress: 46% | Loss: 0.1728 | Accuracy: 0.9330
# Progress: 47% | Loss: 0.1724 | Accuracy: 0.9335
# Progress: 48% | Loss: 0.1712 | Accuracy: 0.9344
# Progress: 49% | Loss: 0.1713 | Accuracy: 0.9340
# Progress: 50% | Loss: 0.1695 | Accuracy: 0.9348
# Progress: 51% | Loss: 0.1697 | Accuracy: 0.9348
# Progress: 52% | Loss: 0.1702 | Accuracy: 0.9352
# Progress: 53% | Loss: 0.1685 | Accuracy: 0.9360
# Progress: 54% | Loss: 0.1678 | Accuracy: 0.9353
# Progress: 55% | Loss: 0.1656 | Accuracy: 0.9363
# Progress: 56% | Loss: 0.1642 | Accuracy: 0.9366
# Progress: 57% | Loss: 0.1637 | Accuracy: 0.9367
# Progress: 58% | Loss: 0.1633 | Accuracy: 0.9370
# Progress: 59% | Loss: 0.1633 | Accuracy: 0.9366
# Progress: 60% | Loss: 0.1646 | Accuracy: 0.9366
# Progress: 61% | Loss: 0.1669 | Accuracy: 0.9357
# Progress: 62% | Loss: 0.1654 | Accuracy: 0.9356
# Progress: 63% | Loss: 0.1652 | Accuracy: 0.9354
# Progress: 64% | Loss: 0.1647 | Accuracy: 0.9354
# Progress: 65% | Loss: 0.1648 | Accuracy: 0.9353
# Progress: 66% | Loss: 0.1641 | Accuracy: 0.9354
# Progress: 67% | Loss: 0.1649 | Accuracy: 0.9343
# Progress: 68% | Loss: 0.1642 | Accuracy: 0.9345
# Progress: 69% | Loss: 0.1637 | Accuracy: 0.9348
# Progress: 70% | Loss: 0.1639 | Accuracy: 0.9341
# Progress: 71% | Loss: 0.1638 | Accuracy: 0.9338
# Progress: 72% | Loss: 0.1622 | Accuracy: 0.9344
# Progress: 73% | Loss: 0.1627 | Accuracy: 0.9339
# Progress: 74% | Loss: 0.1637 | Accuracy: 0.9336
# Progress: 75% | Loss: 0.1626 | Accuracy: 0.9342
# Progress: 76% | Loss: 0.1624 | Accuracy: 0.9339
# Progress: 77% | Loss: 0.1620 | Accuracy: 0.9340
# Progress: 78% | Loss: 0.1619 | Accuracy: 0.9342
# Progress: 79% | Loss: 0.1620 | Accuracy: 0.9338
# Progress: 80% | Loss: 0.1624 | Accuracy: 0.9336
# Progress: 81% | Loss: 0.1614 | Accuracy: 0.9338
# Progress: 82% | Loss: 0.1618 | Accuracy: 0.9339
# Progress: 83% | Loss: 0.1622 | Accuracy: 0.9337
# Progress: 84% | Loss: 0.1621 | Accuracy: 0.9339
# Progress: 85% | Loss: 0.1620 | Accuracy: 0.9342
# Progress: 86% | Loss: 0.1612 | Accuracy: 0.9344
# Progress: 87% | Loss: 0.1611 | Accuracy: 0.9344
# Progress: 88% | Loss: 0.1599 | Accuracy: 0.9349
# Progress: 89% | Loss: 0.1594 | Accuracy: 0.9351
# Progress: 90% | Loss: 0.1589 | Accuracy: 0.9351
# Progress: 91% | Loss: 0.1587 | Accuracy: 0.9355
# Progress: 92% | Loss: 0.1586 | Accuracy: 0.9356
# Progress: 93% | Loss: 0.1589 | Accuracy: 0.9356
# Progress: 94% | Loss: 0.1588 | Accuracy: 0.9358
# Progress: 95% | Loss: 0.1589 | Accuracy: 0.9356
# Progress: 96% | Loss: 0.1586 | Accuracy: 0.9358
# Progress: 97% | Loss: 0.1598 | Accuracy: 0.9350
# Progress: 98% | Loss: 0.1585 | Accuracy: 0.9356
# Progress: 99% | Loss: 0.1582 | Accuracy: 0.9354
# Progress: 100% | Loss: 0.1580 | Accuracy: 0.9350
#   Validation completed in 23.67 seconds.
# Epoch 3/12:
#   Train Loss: 0.1765 | Train Accuracy: 0.9282
#   Val Loss: 0.1580 | Val Accuracy: 0.9354
#   Saved best model to /kaggle/working/best_model_epoch_3_val_acc_0.9354.pth
# Epoch 4: Training...
# Progress: 1% | Loss: 0.1450 | Accuracy: 0.9563
# Progress: 2% | Loss: 0.1362 | Accuracy: 0.9533
# Progress: 3% | Loss: 0.1300 | Accuracy: 0.9577
# Progress: 4% | Loss: 0.1171 | Accuracy: 0.9609
# Progress: 5% | Loss: 0.1221 | Accuracy: 0.9587
# Progress: 6% | Loss: 0.1243 | Accuracy: 0.9559
# Progress: 7% | Loss: 0.1296 | Accuracy: 0.9509
# Progress: 8% | Loss: 0.1250 | Accuracy: 0.9529
# Progress: 9% | Loss: 0.1244 | Accuracy: 0.9544
# Progress: 10% | Loss: 0.1233 | Accuracy: 0.9546
# Progress: 11% | Loss: 0.1276 | Accuracy: 0.9538
# Progress: 12% | Loss: 0.1248 | Accuracy: 0.9552
# Progress: 13% | Loss: 0.1256 | Accuracy: 0.9545
# Progress: 14% | Loss: 0.1264 | Accuracy: 0.9533
# Progress: 15% | Loss: 0.1293 | Accuracy: 0.9517
# Progress: 16% | Loss: 0.1279 | Accuracy: 0.9516
# Progress: 17% | Loss: 0.1276 | Accuracy: 0.9513
# Progress: 18% | Loss: 0.1247 | Accuracy: 0.9530
# Progress: 19% | Loss: 0.1227 | Accuracy: 0.9539
# Progress: 20% | Loss: 0.1187 | Accuracy: 0.9553
# Progress: 21% | Loss: 0.1186 | Accuracy: 0.9555
# Progress: 22% | Loss: 0.1223 | Accuracy: 0.9543
# Progress: 23% | Loss: 0.1241 | Accuracy: 0.9539
# Progress: 24% | Loss: 0.1250 | Accuracy: 0.9543
# Progress: 25% | Loss: 0.1253 | Accuracy: 0.9541
# Progress: 26% | Loss: 0.1253 | Accuracy: 0.9536
# Progress: 27% | Loss: 0.1251 | Accuracy: 0.9537
# Progress: 28% | Loss: 0.1243 | Accuracy: 0.9542
# Progress: 29% | Loss: 0.1242 | Accuracy: 0.9546
# Progress: 30% | Loss: 0.1235 | Accuracy: 0.9545
# Progress: 31% | Loss: 0.1259 | Accuracy: 0.9537
# Progress: 32% | Loss: 0.1269 | Accuracy: 0.9530
# Progress: 33% | Loss: 0.1271 | Accuracy: 0.9531
# Progress: 34% | Loss: 0.1273 | Accuracy: 0.9531
# Progress: 35% | Loss: 0.1275 | Accuracy: 0.9529
# Progress: 36% | Loss: 0.1276 | Accuracy: 0.9530
# Progress: 37% | Loss: 0.1287 | Accuracy: 0.9527
# Progress: 38% | Loss: 0.1274 | Accuracy: 0.9532
# Progress: 39% | Loss: 0.1261 | Accuracy: 0.9540
# Progress: 40% | Loss: 0.1259 | Accuracy: 0.9540
# Progress: 41% | Loss: 0.1254 | Accuracy: 0.9544
# Progress: 42% | Loss: 0.1252 | Accuracy: 0.9544
# Progress: 43% | Loss: 0.1254 | Accuracy: 0.9541
# Progress: 44% | Loss: 0.1247 | Accuracy: 0.9544
# Progress: 45% | Loss: 0.1245 | Accuracy: 0.9543
# Progress: 46% | Loss: 0.1258 | Accuracy: 0.9533
# Progress: 47% | Loss: 0.1256 | Accuracy: 0.9534
# Progress: 48% | Loss: 0.1266 | Accuracy: 0.9526
# Progress: 49% | Loss: 0.1264 | Accuracy: 0.9525
# Progress: 50% | Loss: 0.1268 | Accuracy: 0.9521
# Progress: 51% | Loss: 0.1266 | Accuracy: 0.9522
# Progress: 52% | Loss: 0.1282 | Accuracy: 0.9517
# Progress: 53% | Loss: 0.1278 | Accuracy: 0.9519
# Progress: 54% | Loss: 0.1277 | Accuracy: 0.9520
# Progress: 55% | Loss: 0.1282 | Accuracy: 0.9518
# Progress: 56% | Loss: 0.1275 | Accuracy: 0.9522
# Progress: 57% | Loss: 0.1265 | Accuracy: 0.9526
# Progress: 58% | Loss: 0.1262 | Accuracy: 0.9527
# Progress: 59% | Loss: 0.1254 | Accuracy: 0.9528
# Progress: 60% | Loss: 0.1251 | Accuracy: 0.9529
# Progress: 61% | Loss: 0.1243 | Accuracy: 0.9531
# Progress: 62% | Loss: 0.1241 | Accuracy: 0.9534
# Progress: 63% | Loss: 0.1235 | Accuracy: 0.9536
# Progress: 64% | Loss: 0.1233 | Accuracy: 0.9537
# Progress: 65% | Loss: 0.1229 | Accuracy: 0.9539
# Progress: 66% | Loss: 0.1229 | Accuracy: 0.9539
# Progress: 67% | Loss: 0.1229 | Accuracy: 0.9539
# Progress: 68% | Loss: 0.1230 | Accuracy: 0.9538
# Progress: 69% | Loss: 0.1228 | Accuracy: 0.9540
# Progress: 70% | Loss: 0.1228 | Accuracy: 0.9541
# Progress: 71% | Loss: 0.1221 | Accuracy: 0.9544
# Progress: 72% | Loss: 0.1219 | Accuracy: 0.9545
# Progress: 73% | Loss: 0.1215 | Accuracy: 0.9545
# Progress: 74% | Loss: 0.1216 | Accuracy: 0.9546
# Progress: 75% | Loss: 0.1218 | Accuracy: 0.9547
# Progress: 76% | Loss: 0.1224 | Accuracy: 0.9543
# Progress: 77% | Loss: 0.1220 | Accuracy: 0.9543
# Progress: 78% | Loss: 0.1218 | Accuracy: 0.9544
# Progress: 79% | Loss: 0.1221 | Accuracy: 0.9543
# Progress: 80% | Loss: 0.1223 | Accuracy: 0.9542
# Progress: 81% | Loss: 0.1217 | Accuracy: 0.9544
# Progress: 82% | Loss: 0.1217 | Accuracy: 0.9543
# Progress: 83% | Loss: 0.1217 | Accuracy: 0.9543
# Progress: 84% | Loss: 0.1215 | Accuracy: 0.9543
# Progress: 85% | Loss: 0.1219 | Accuracy: 0.9542
# Progress: 86% | Loss: 0.1219 | Accuracy: 0.9542
# Progress: 87% | Loss: 0.1221 | Accuracy: 0.9543
# Progress: 88% | Loss: 0.1215 | Accuracy: 0.9545
# Progress: 89% | Loss: 0.1214 | Accuracy: 0.9545
# Progress: 90% | Loss: 0.1209 | Accuracy: 0.9547
# Progress: 91% | Loss: 0.1203 | Accuracy: 0.9550
# Progress: 92% | Loss: 0.1204 | Accuracy: 0.9547
# Progress: 93% | Loss: 0.1199 | Accuracy: 0.9550
# Progress: 94% | Loss: 0.1198 | Accuracy: 0.9551
# Progress: 95% | Loss: 0.1197 | Accuracy: 0.9550
# Progress: 96% | Loss: 0.1195 | Accuracy: 0.9550
# Progress: 97% | Loss: 0.1193 | Accuracy: 0.9550
# Progress: 98% | Loss: 0.1193 | Accuracy: 0.9551
# Progress: 99% | Loss: 0.1190 | Accuracy: 0.9552
# Progress: 100% | Loss: 0.1189 | Accuracy: 0.9552
#   Training completed in 314.92 seconds.
# Epoch 4: Evaluating (Validation)...
# Progress: 1% | Loss: 0.0954 | Accuracy: 0.9833
# Progress: 2% | Loss: 0.1459 | Accuracy: 0.9537
# Progress: 3% | Loss: 0.1772 | Accuracy: 0.9423
# Progress: 4% | Loss: 0.1620 | Accuracy: 0.9398
# Progress: 5% | Loss: 0.1525 | Accuracy: 0.9432
# Progress: 6% | Loss: 0.1619 | Accuracy: 0.9423
# Progress: 7% | Loss: 0.1722 | Accuracy: 0.9435
# Progress: 8% | Loss: 0.1701 | Accuracy: 0.9429
# Progress: 9% | Loss: 0.1606 | Accuracy: 0.9466
# Progress: 10% | Loss: 0.1734 | Accuracy: 0.9451
# Progress: 11% | Loss: 0.1771 | Accuracy: 0.9444
# Progress: 12% | Loss: 0.1678 | Accuracy: 0.9471
# Progress: 13% | Loss: 0.1916 | Accuracy: 0.9401
# Progress: 14% | Loss: 0.1910 | Accuracy: 0.9385
# Progress: 15% | Loss: 0.1982 | Accuracy: 0.9372
# Progress: 16% | Loss: 0.1937 | Accuracy: 0.9372
# Progress: 17% | Loss: 0.1835 | Accuracy: 0.9403
# Progress: 18% | Loss: 0.1913 | Accuracy: 0.9391
# Progress: 19% | Loss: 0.1924 | Accuracy: 0.9390
# Progress: 20% | Loss: 0.1961 | Accuracy: 0.9387
# Progress: 21% | Loss: 0.1983 | Accuracy: 0.9377
# Progress: 22% | Loss: 0.1913 | Accuracy: 0.9404
# Progress: 23% | Loss: 0.1829 | Accuracy: 0.9433
# Progress: 24% | Loss: 0.1808 | Accuracy: 0.9431
# Progress: 25% | Loss: 0.1959 | Accuracy: 0.9390
# Progress: 26% | Loss: 0.1965 | Accuracy: 0.9373
# Progress: 27% | Loss: 0.1973 | Accuracy: 0.9366
# Progress: 28% | Loss: 0.2037 | Accuracy: 0.9353
# Progress: 29% | Loss: 0.2025 | Accuracy: 0.9353
# Progress: 30% | Loss: 0.1974 | Accuracy: 0.9365
# Progress: 31% | Loss: 0.2051 | Accuracy: 0.9347
# Progress: 32% | Loss: 0.2070 | Accuracy: 0.9348
# Progress: 33% | Loss: 0.2066 | Accuracy: 0.9347
# Progress: 34% | Loss: 0.2029 | Accuracy: 0.9354
# Progress: 35% | Loss: 0.2065 | Accuracy: 0.9343
# Progress: 36% | Loss: 0.2072 | Accuracy: 0.9332
# Progress: 37% | Loss: 0.2146 | Accuracy: 0.9302
# Progress: 38% | Loss: 0.2139 | Accuracy: 0.9304
# Progress: 39% | Loss: 0.2115 | Accuracy: 0.9310
# Progress: 40% | Loss: 0.2081 | Accuracy: 0.9321
# Progress: 41% | Loss: 0.2089 | Accuracy: 0.9317
# Progress: 42% | Loss: 0.2136 | Accuracy: 0.9304
# Progress: 43% | Loss: 0.2121 | Accuracy: 0.9310
# Progress: 44% | Loss: 0.2097 | Accuracy: 0.9316
# Progress: 45% | Loss: 0.2068 | Accuracy: 0.9326
# Progress: 46% | Loss: 0.2097 | Accuracy: 0.9309
# Progress: 47% | Loss: 0.2090 | Accuracy: 0.9314
# Progress: 48% | Loss: 0.2072 | Accuracy: 0.9320
# Progress: 49% | Loss: 0.2057 | Accuracy: 0.9320
# Progress: 50% | Loss: 0.2037 | Accuracy: 0.9329
# Progress: 51% | Loss: 0.2007 | Accuracy: 0.9341
# Progress: 52% | Loss: 0.1988 | Accuracy: 0.9348
# Progress: 53% | Loss: 0.1969 | Accuracy: 0.9352
# Progress: 54% | Loss: 0.1963 | Accuracy: 0.9356
# Progress: 55% | Loss: 0.1932 | Accuracy: 0.9366
# Progress: 56% | Loss: 0.1908 | Accuracy: 0.9373
# Progress: 57% | Loss: 0.1897 | Accuracy: 0.9373
# Progress: 58% | Loss: 0.1888 | Accuracy: 0.9377
# Progress: 59% | Loss: 0.1880 | Accuracy: 0.9376
# Progress: 60% | Loss: 0.1892 | Accuracy: 0.9376
# Progress: 61% | Loss: 0.1904 | Accuracy: 0.9369
# Progress: 62% | Loss: 0.1890 | Accuracy: 0.9372
# Progress: 63% | Loss: 0.1892 | Accuracy: 0.9372
# Progress: 64% | Loss: 0.1885 | Accuracy: 0.9375
# Progress: 65% | Loss: 0.1881 | Accuracy: 0.9377
# Progress: 66% | Loss: 0.1873 | Accuracy: 0.9383
# Progress: 67% | Loss: 0.1881 | Accuracy: 0.9377
# Progress: 68% | Loss: 0.1869 | Accuracy: 0.9382
# Progress: 69% | Loss: 0.1860 | Accuracy: 0.9388
# Progress: 70% | Loss: 0.1847 | Accuracy: 0.9393
# Progress: 71% | Loss: 0.1846 | Accuracy: 0.9395
# Progress: 72% | Loss: 0.1829 | Accuracy: 0.9400
# Progress: 73% | Loss: 0.1837 | Accuracy: 0.9399
# Progress: 74% | Loss: 0.1861 | Accuracy: 0.9397
# Progress: 75% | Loss: 0.1856 | Accuracy: 0.9401
# Progress: 76% | Loss: 0.1869 | Accuracy: 0.9390
# Progress: 77% | Loss: 0.1866 | Accuracy: 0.9393
# Progress: 78% | Loss: 0.1866 | Accuracy: 0.9392
# Progress: 79% | Loss: 0.1872 | Accuracy: 0.9384
# Progress: 80% | Loss: 0.1887 | Accuracy: 0.9377
# Progress: 81% | Loss: 0.1881 | Accuracy: 0.9374
# Progress: 82% | Loss: 0.1883 | Accuracy: 0.9376
# Progress: 83% | Loss: 0.1895 | Accuracy: 0.9372
# Progress: 84% | Loss: 0.1894 | Accuracy: 0.9373
# Progress: 85% | Loss: 0.1881 | Accuracy: 0.9376
# Progress: 86% | Loss: 0.1876 | Accuracy: 0.9378
# Progress: 87% | Loss: 0.1877 | Accuracy: 0.9376
# Progress: 88% | Loss: 0.1865 | Accuracy: 0.9382
# Progress: 89% | Loss: 0.1852 | Accuracy: 0.9384
# Progress: 90% | Loss: 0.1851 | Accuracy: 0.9384
# Progress: 91% | Loss: 0.1843 | Accuracy: 0.9387
# Progress: 92% | Loss: 0.1833 | Accuracy: 0.9391
# Progress: 93% | Loss: 0.1836 | Accuracy: 0.9391
# Progress: 94% | Loss: 0.1825 | Accuracy: 0.9394
# Progress: 95% | Loss: 0.1836 | Accuracy: 0.9386
# Progress: 96% | Loss: 0.1822 | Accuracy: 0.9390
# Progress: 97% | Loss: 0.1838 | Accuracy: 0.9385
# Progress: 98% | Loss: 0.1824 | Accuracy: 0.9389
# Progress: 99% | Loss: 0.1818 | Accuracy: 0.9389
# Progress: 100% | Loss: 0.1823 | Accuracy: 0.9385
#   Validation completed in 23.68 seconds.
# Epoch 4/12:
#   Train Loss: 0.1189 | Train Accuracy: 0.9554
#   Val Loss: 0.1823 | Val Accuracy: 0.9389
#   Saved best model to /kaggle/working/best_model_epoch_4_val_acc_0.9389.pth
# Epoch 5: Training...
# Progress: 1% | Loss: 0.0570 | Accuracy: 0.9841
# Progress: 2% | Loss: 0.0844 | Accuracy: 0.9736
# Progress: 3% | Loss: 0.0804 | Accuracy: 0.9740
# Progress: 4% | Loss: 0.0816 | Accuracy: 0.9712
# Progress: 5% | Loss: 0.0740 | Accuracy: 0.9736
# Progress: 6% | Loss: 0.0762 | Accuracy: 0.9738
# Progress: 7% | Loss: 0.0727 | Accuracy: 0.9758
# Progress: 8% | Loss: 0.0666 | Accuracy: 0.9777
# Progress: 9% | Loss: 0.0672 | Accuracy: 0.9770
# Progress: 10% | Loss: 0.0665 | Accuracy: 0.9765
# Progress: 11% | Loss: 0.0656 | Accuracy: 0.9775
# Progress: 12% | Loss: 0.0731 | Accuracy: 0.9756
# Progress: 13% | Loss: 0.0758 | Accuracy: 0.9739
# Progress: 14% | Loss: 0.0747 | Accuracy: 0.9749
# Progress: 15% | Loss: 0.0754 | Accuracy: 0.9749
# Progress: 16% | Loss: 0.0777 | Accuracy: 0.9744
# Progress: 17% | Loss: 0.0758 | Accuracy: 0.9754
# Progress: 18% | Loss: 0.0749 | Accuracy: 0.9756
# Progress: 19% | Loss: 0.0757 | Accuracy: 0.9756
# Progress: 20% | Loss: 0.0756 | Accuracy: 0.9748
# Progress: 21% | Loss: 0.0756 | Accuracy: 0.9746
# Progress: 22% | Loss: 0.0753 | Accuracy: 0.9744
# Progress: 23% | Loss: 0.0765 | Accuracy: 0.9739
# Progress: 24% | Loss: 0.0772 | Accuracy: 0.9736
# Progress: 25% | Loss: 0.0761 | Accuracy: 0.9743
# Progress: 26% | Loss: 0.0761 | Accuracy: 0.9742
# Progress: 27% | Loss: 0.0757 | Accuracy: 0.9742
# Progress: 28% | Loss: 0.0745 | Accuracy: 0.9744
# Progress: 29% | Loss: 0.0747 | Accuracy: 0.9740
# Progress: 30% | Loss: 0.0741 | Accuracy: 0.9741
# Progress: 31% | Loss: 0.0739 | Accuracy: 0.9740
# Progress: 32% | Loss: 0.0736 | Accuracy: 0.9739
# Progress: 33% | Loss: 0.0750 | Accuracy: 0.9733
# Progress: 34% | Loss: 0.0751 | Accuracy: 0.9728
# Progress: 35% | Loss: 0.0743 | Accuracy: 0.9731
# Progress: 36% | Loss: 0.0751 | Accuracy: 0.9726
# Progress: 37% | Loss: 0.0752 | Accuracy: 0.9725
# Progress: 38% | Loss: 0.0750 | Accuracy: 0.9728
# Progress: 39% | Loss: 0.0761 | Accuracy: 0.9723
# Progress: 40% | Loss: 0.0764 | Accuracy: 0.9722
# Progress: 41% | Loss: 0.0765 | Accuracy: 0.9719
# Progress: 42% | Loss: 0.0769 | Accuracy: 0.9720
# Progress: 43% | Loss: 0.0768 | Accuracy: 0.9718
# Progress: 44% | Loss: 0.0765 | Accuracy: 0.9720
# Progress: 45% | Loss: 0.0756 | Accuracy: 0.9725
# Progress: 46% | Loss: 0.0754 | Accuracy: 0.9726
# Progress: 47% | Loss: 0.0765 | Accuracy: 0.9722
# Progress: 48% | Loss: 0.0766 | Accuracy: 0.9720
# Progress: 49% | Loss: 0.0770 | Accuracy: 0.9720
# Progress: 50% | Loss: 0.0775 | Accuracy: 0.9718
# Progress: 51% | Loss: 0.0775 | Accuracy: 0.9716
# Progress: 52% | Loss: 0.0780 | Accuracy: 0.9712
# Progress: 53% | Loss: 0.0782 | Accuracy: 0.9714
# Progress: 54% | Loss: 0.0785 | Accuracy: 0.9712
# Progress: 55% | Loss: 0.0782 | Accuracy: 0.9713
# Progress: 56% | Loss: 0.0780 | Accuracy: 0.9713
# Progress: 57% | Loss: 0.0776 | Accuracy: 0.9715
# Progress: 58% | Loss: 0.0773 | Accuracy: 0.9716
# Progress: 59% | Loss: 0.0775 | Accuracy: 0.9716
# Progress: 60% | Loss: 0.0774 | Accuracy: 0.9716
# Progress: 61% | Loss: 0.0785 | Accuracy: 0.9713
# Progress: 62% | Loss: 0.0790 | Accuracy: 0.9711
# Progress: 63% | Loss: 0.0793 | Accuracy: 0.9709
# Progress: 64% | Loss: 0.0794 | Accuracy: 0.9708
# Progress: 65% | Loss: 0.0790 | Accuracy: 0.9710
# Progress: 66% | Loss: 0.0790 | Accuracy: 0.9710
# Progress: 67% | Loss: 0.0792 | Accuracy: 0.9708
# Progress: 68% | Loss: 0.0797 | Accuracy: 0.9706
# Progress: 69% | Loss: 0.0800 | Accuracy: 0.9702
# Progress: 70% | Loss: 0.0798 | Accuracy: 0.9704
# Progress: 71% | Loss: 0.0796 | Accuracy: 0.9705
# Progress: 72% | Loss: 0.0794 | Accuracy: 0.9705
# Progress: 73% | Loss: 0.0790 | Accuracy: 0.9706
# Progress: 74% | Loss: 0.0794 | Accuracy: 0.9704
# Progress: 75% | Loss: 0.0791 | Accuracy: 0.9706
# Progress: 76% | Loss: 0.0790 | Accuracy: 0.9705
# Progress: 77% | Loss: 0.0790 | Accuracy: 0.9706
# Progress: 78% | Loss: 0.0794 | Accuracy: 0.9705
# Progress: 79% | Loss: 0.0795 | Accuracy: 0.9704
# Progress: 80% | Loss: 0.0794 | Accuracy: 0.9704
# Progress: 81% | Loss: 0.0793 | Accuracy: 0.9703
# Progress: 82% | Loss: 0.0797 | Accuracy: 0.9702
# Progress: 83% | Loss: 0.0798 | Accuracy: 0.9703
# Progress: 84% | Loss: 0.0798 | Accuracy: 0.9703
# Progress: 85% | Loss: 0.0797 | Accuracy: 0.9704
# Progress: 86% | Loss: 0.0795 | Accuracy: 0.9705
# Progress: 87% | Loss: 0.0792 | Accuracy: 0.9707
# Progress: 88% | Loss: 0.0792 | Accuracy: 0.9707
# Progress: 89% | Loss: 0.0795 | Accuracy: 0.9705
# Progress: 90% | Loss: 0.0794 | Accuracy: 0.9706
# Progress: 91% | Loss: 0.0793 | Accuracy: 0.9707
# Progress: 92% | Loss: 0.0794 | Accuracy: 0.9707
# Progress: 93% | Loss: 0.0792 | Accuracy: 0.9708
# Progress: 94% | Loss: 0.0787 | Accuracy: 0.9710
# Progress: 95% | Loss: 0.0790 | Accuracy: 0.9709
# Progress: 96% | Loss: 0.0787 | Accuracy: 0.9710
# Progress: 97% | Loss: 0.0786 | Accuracy: 0.9709
# Progress: 98% | Loss: 0.0783 | Accuracy: 0.9711
# Progress: 99% | Loss: 0.0780 | Accuracy: 0.9712
# Progress: 100% | Loss: 0.0784 | Accuracy: 0.9709
#   Training completed in 315.20 seconds.
# Epoch 5: Evaluating (Validation)...
# Progress: 1% | Loss: 0.1207 | Accuracy: 0.9667
# Progress: 2% | Loss: 0.0958 | Accuracy: 0.9722
# Progress: 3% | Loss: 0.1267 | Accuracy: 0.9615
# Progress: 4% | Loss: 0.1098 | Accuracy: 0.9676
# Progress: 5% | Loss: 0.1065 | Accuracy: 0.9697
# Progress: 6% | Loss: 0.1152 | Accuracy: 0.9679
# Progress: 7% | Loss: 0.1188 | Accuracy: 0.9704
# Progress: 8% | Loss: 0.1283 | Accuracy: 0.9667
# Progress: 9% | Loss: 0.1155 | Accuracy: 0.9701
# Progress: 10% | Loss: 0.1205 | Accuracy: 0.9697
# Progress: 11% | Loss: 0.1263 | Accuracy: 0.9670
# Progress: 12% | Loss: 0.1250 | Accuracy: 0.9663
# Progress: 13% | Loss: 0.1485 | Accuracy: 0.9576
# Progress: 14% | Loss: 0.1456 | Accuracy: 0.9590
# Progress: 15% | Loss: 0.1518 | Accuracy: 0.9590
# Progress: 16% | Loss: 0.1434 | Accuracy: 0.9614
# Progress: 17% | Loss: 0.1349 | Accuracy: 0.9628
# Progress: 18% | Loss: 0.1305 | Accuracy: 0.9637
# Progress: 19% | Loss: 0.1347 | Accuracy: 0.9624
# Progress: 20% | Loss: 0.1392 | Accuracy: 0.9617
# Progress: 21% | Loss: 0.1390 | Accuracy: 0.9615
# Progress: 22% | Loss: 0.1335 | Accuracy: 0.9632
# Progress: 23% | Loss: 0.1294 | Accuracy: 0.9633
# Progress: 24% | Loss: 0.1269 | Accuracy: 0.9639
# Progress: 25% | Loss: 0.1410 | Accuracy: 0.9599
# Progress: 26% | Loss: 0.1423 | Accuracy: 0.9587
# Progress: 27% | Loss: 0.1435 | Accuracy: 0.9580
# Progress: 28% | Loss: 0.1494 | Accuracy: 0.9566
# Progress: 29% | Loss: 0.1500 | Accuracy: 0.9560
# Progress: 30% | Loss: 0.1455 | Accuracy: 0.9571
# Progress: 31% | Loss: 0.1578 | Accuracy: 0.9552
# Progress: 32% | Loss: 0.1601 | Accuracy: 0.9541
# Progress: 33% | Loss: 0.1600 | Accuracy: 0.9534
# Progress: 34% | Loss: 0.1580 | Accuracy: 0.9535
# Progress: 35% | Loss: 0.1572 | Accuracy: 0.9531
# Progress: 36% | Loss: 0.1546 | Accuracy: 0.9535
# Progress: 37% | Loss: 0.1607 | Accuracy: 0.9516
# Progress: 38% | Loss: 0.1619 | Accuracy: 0.9517
# Progress: 39% | Loss: 0.1593 | Accuracy: 0.9527
# Progress: 40% | Loss: 0.1574 | Accuracy: 0.9533
# Progress: 41% | Loss: 0.1615 | Accuracy: 0.9515
# Progress: 42% | Loss: 0.1648 | Accuracy: 0.9510
# Progress: 43% | Loss: 0.1631 | Accuracy: 0.9516
# Progress: 44% | Loss: 0.1605 | Accuracy: 0.9522
# Progress: 45% | Loss: 0.1574 | Accuracy: 0.9532
# Progress: 46% | Loss: 0.1595 | Accuracy: 0.9523
# Progress: 47% | Loss: 0.1587 | Accuracy: 0.9524
# Progress: 48% | Loss: 0.1573 | Accuracy: 0.9529
# Progress: 49% | Loss: 0.1575 | Accuracy: 0.9532
# Progress: 50% | Loss: 0.1561 | Accuracy: 0.9537
# Progress: 51% | Loss: 0.1548 | Accuracy: 0.9534
# Progress: 52% | Loss: 0.1551 | Accuracy: 0.9533
# Progress: 53% | Loss: 0.1538 | Accuracy: 0.9534
# Progress: 54% | Loss: 0.1536 | Accuracy: 0.9535
# Progress: 55% | Loss: 0.1515 | Accuracy: 0.9541
# Progress: 56% | Loss: 0.1500 | Accuracy: 0.9545
# Progress: 57% | Loss: 0.1489 | Accuracy: 0.9549
# Progress: 58% | Loss: 0.1498 | Accuracy: 0.9550
# Progress: 59% | Loss: 0.1509 | Accuracy: 0.9546
# Progress: 60% | Loss: 0.1535 | Accuracy: 0.9543
# Progress: 61% | Loss: 0.1563 | Accuracy: 0.9534
# Progress: 62% | Loss: 0.1541 | Accuracy: 0.9540
# ...
# Progress: 83% | Loss: 0.0172 | Accuracy: 0.9936
# Progress: 84% | Loss: 0.0174 | Accuracy: 0.9935
# Progress: 85% | Loss: 0.0176 | Accuracy: 0.9935
# Progress: 86% | Loss: 0.0179 | Accuracy: 0.9934
# Progress: 87% | Loss: 0.0181 | Accuracy: 0.9934
# Progress: 88% | Loss: 0.0184 | Accuracy: 0.9933
# Progress: 89% | Loss: 0.0182 | Accuracy: 0.9933
# Progress: 90% | Loss: 0.0183 | Accuracy: 0.9934
# Progress: 91% | Loss: 0.0181 | Accuracy: 0.9934
# Progress: 92% | Loss: 0.0182 | Accuracy: 0.9935
# Progress: 93% | Loss: 0.0180 | Accuracy: 0.9935
# Progress: 94% | Loss: 0.0180 | Accuracy: 0.9936
# Progress: 95% | Loss: 0.0180 | Accuracy: 0.9935
# Progress: 96% | Loss: 0.0179 | Accuracy: 0.9936
# Progress: 97% | Loss: 0.0184 | Accuracy: 0.9934
# Progress: 98% | Loss: 0.0185 | Accuracy: 0.9934
# Progress: 99% | Loss: 0.0185 | Accuracy: 0.9933
# Progress: 100% | Loss: 0.0185 | Accuracy: 0.9932
#   Training completed in 315.24 seconds.
# Epoch 11: Evaluating (Validation)...
# Progress: 1% | Loss: 0.1625 | Accuracy: 0.9667
# Progress: 2% | Loss: 0.1255 | Accuracy: 0.9722
# Progress: 3% | Loss: 0.1684 | Accuracy: 0.9679
# Progress: 4% | Loss: 0.1276 | Accuracy: 0.9722
# Progress: 5% | Loss: 0.1141 | Accuracy: 0.9697
# Progress: 6% | Loss: 0.1347 | Accuracy: 0.9679
# Progress: 7% | Loss: 0.1351 | Accuracy: 0.9704
# Progress: 8% | Loss: 0.1467 | Accuracy: 0.9667
# Progress: 9% | Loss: 0.1317 | Accuracy: 0.9701
# Progress: 10% | Loss: 0.1248 | Accuracy: 0.9697
# Progress: 11% | Loss: 0.1390 | Accuracy: 0.9670
# Progress: 12% | Loss: 0.1473 | Accuracy: 0.9663
# Progress: 13% | Loss: 0.1874 | Accuracy: 0.9591
# Progress: 14% | Loss: 0.1824 | Accuracy: 0.9604
# Progress: 15% | Loss: 0.1943 | Accuracy: 0.9577
# Progress: 16% | Loss: 0.1838 | Accuracy: 0.9601
# Progress: 17% | Loss: 0.1731 | Accuracy: 0.9617
# Progress: 18% | Loss: 0.1735 | Accuracy: 0.9626
# Progress: 19% | Loss: 0.1787 | Accuracy: 0.9624
# Progress: 20% | Loss: 0.1770 | Accuracy: 0.9626
# Progress: 21% | Loss: 0.1756 | Accuracy: 0.9634
# Progress: 22% | Loss: 0.1682 | Accuracy: 0.9649
# Progress: 23% | Loss: 0.1679 | Accuracy: 0.9650
# Progress: 24% | Loss: 0.1615 | Accuracy: 0.9663
# Progress: 25% | Loss: 0.1758 | Accuracy: 0.9630
# Progress: 26% | Loss: 0.1747 | Accuracy: 0.9631
# Progress: 27% | Loss: 0.1746 | Accuracy: 0.9637
# Progress: 28% | Loss: 0.1808 | Accuracy: 0.9628
# Progress: 29% | Loss: 0.1829 | Accuracy: 0.9620
# Progress: 30% | Loss: 0.1783 | Accuracy: 0.9628
# Progress: 31% | Loss: 0.1854 | Accuracy: 0.9608
# Progress: 32% | Loss: 0.1873 | Accuracy: 0.9607
# Progress: 33% | Loss: 0.1888 | Accuracy: 0.9604
# Progress: 34% | Loss: 0.1855 | Accuracy: 0.9603
# Progress: 35% | Loss: 0.1848 | Accuracy: 0.9586
# Progress: 36% | Loss: 0.1817 | Accuracy: 0.9594
# Progress: 37% | Loss: 0.1918 | Accuracy: 0.9573
# Progress: 38% | Loss: 0.1924 | Accuracy: 0.9568
# Progress: 39% | Loss: 0.1868 | Accuracy: 0.9581
# Progress: 40% | Loss: 0.1864 | Accuracy: 0.9586
# Progress: 41% | Loss: 0.1862 | Accuracy: 0.9581
# Progress: 42% | Loss: 0.1907 | Accuracy: 0.9574
# Progress: 43% | Loss: 0.1870 | Accuracy: 0.9579
# Progress: 44% | Loss: 0.1832 | Accuracy: 0.9588
# Progress: 45% | Loss: 0.1798 | Accuracy: 0.9592
# Progress: 46% | Loss: 0.1808 | Accuracy: 0.9585
# Progress: 47% | Loss: 0.1803 | Accuracy: 0.9585
# Progress: 48% | Loss: 0.1791 | Accuracy: 0.9589
# Progress: 49% | Loss: 0.1798 | Accuracy: 0.9591
# Progress: 50% | Loss: 0.1786 | Accuracy: 0.9595
# Progress: 51% | Loss: 0.1782 | Accuracy: 0.9595
# Progress: 52% | Loss: 0.1766 | Accuracy: 0.9596
# Progress: 53% | Loss: 0.1770 | Accuracy: 0.9592
# Progress: 54% | Loss: 0.1771 | Accuracy: 0.9592
# Progress: 55% | Loss: 0.1744 | Accuracy: 0.9597
# Progress: 56% | Loss: 0.1734 | Accuracy: 0.9601
# Progress: 57% | Loss: 0.1725 | Accuracy: 0.9604
# Progress: 58% | Loss: 0.1723 | Accuracy: 0.9603
# Progress: 59% | Loss: 0.1756 | Accuracy: 0.9595
# Progress: 60% | Loss: 0.1746 | Accuracy: 0.9595
# Progress: 61% | Loss: 0.1789 | Accuracy: 0.9582
# Progress: 62% | Loss: 0.1778 | Accuracy: 0.9583
# Progress: 63% | Loss: 0.1757 | Accuracy: 0.9586
# Progress: 64% | Loss: 0.1748 | Accuracy: 0.9589
# Progress: 65% | Loss: 0.1757 | Accuracy: 0.9591
# Progress: 66% | Loss: 0.1754 | Accuracy: 0.9591
# Progress: 67% | Loss: 0.1800 | Accuracy: 0.9585
# Progress: 68% | Loss: 0.1775 | Accuracy: 0.9592
# Progress: 69% | Loss: 0.1764 | Accuracy: 0.9595
# Progress: 70% | Loss: 0.1762 | Accuracy: 0.9597
# Progress: 71% | Loss: 0.1775 | Accuracy: 0.9598
# Progress: 72% | Loss: 0.1766 | Accuracy: 0.9601
# Progress: 73% | Loss: 0.1768 | Accuracy: 0.9598
# Progress: 74% | Loss: 0.1783 | Accuracy: 0.9598
# Progress: 75% | Loss: 0.1764 | Accuracy: 0.9599
# Progress: 76% | Loss: 0.1758 | Accuracy: 0.9599
# Progress: 77% | Loss: 0.1765 | Accuracy: 0.9598
# Progress: 78% | Loss: 0.1786 | Accuracy: 0.9594
# Progress: 79% | Loss: 0.1778 | Accuracy: 0.9594
# Progress: 80% | Loss: 0.1773 | Accuracy: 0.9597
# Progress: 81% | Loss: 0.1769 | Accuracy: 0.9600
# Progress: 82% | Loss: 0.1768 | Accuracy: 0.9602
# Progress: 83% | Loss: 0.1759 | Accuracy: 0.9602
# Progress: 84% | Loss: 0.1766 | Accuracy: 0.9598
# Progress: 85% | Loss: 0.1751 | Accuracy: 0.9600
# Progress: 86% | Loss: 0.1755 | Accuracy: 0.9600
# Progress: 87% | Loss: 0.1753 | Accuracy: 0.9602
# Progress: 88% | Loss: 0.1741 | Accuracy: 0.9601
# Progress: 89% | Loss: 0.1723 | Accuracy: 0.9605
# Progress: 90% | Loss: 0.1727 | Accuracy: 0.9605
# Progress: 91% | Loss: 0.1727 | Accuracy: 0.9606
# Progress: 92% | Loss: 0.1728 | Accuracy: 0.9603
# Progress: 93% | Loss: 0.1744 | Accuracy: 0.9601
# Progress: 94% | Loss: 0.1723 | Accuracy: 0.9606
# Progress: 95% | Loss: 0.1732 | Accuracy: 0.9606
# Progress: 96% | Loss: 0.1717 | Accuracy: 0.9607
# Progress: 97% | Loss: 0.1723 | Accuracy: 0.9606
# Progress: 98% | Loss: 0.1713 | Accuracy: 0.9608
# Progress: 99% | Loss: 0.1702 | Accuracy: 0.9608
# Progress: 100% | Loss: 0.1689 | Accuracy: 0.9606
#   Validation completed in 23.65 seconds.
# Epoch 11/12:
#   Train Loss: 0.0185 | Train Accuracy: 0.9934
#   Val Loss: 0.1689 | Val Accuracy: 0.9609
#   Saved best model to /kaggle/working/best_model_epoch_11_val_acc_0.9609.pth
# Epoch 12: Training...
# Progress: 1% | Loss: 0.0096 | Accuracy: 0.9960
# Progress: 2% | Loss: 0.0302 | Accuracy: 0.9898
# Progress: 3% | Loss: 0.0246 | Accuracy: 0.9918
# Progress: 4% | Loss: 0.0257 | Accuracy: 0.9928
# Progress: 5% | Loss: 0.0229 | Accuracy: 0.9926
# Progress: 6% | Loss: 0.0203 | Accuracy: 0.9938
# Progress: 7% | Loss: 0.0183 | Accuracy: 0.9947
# Progress: 8% | Loss: 0.0194 | Accuracy: 0.9938
# Progress: 9% | Loss: 0.0174 | Accuracy: 0.9945
# Progress: 10% | Loss: 0.0177 | Accuracy: 0.9946
# Progress: 11% | Loss: 0.0169 | Accuracy: 0.9951
# Progress: 12% | Loss: 0.0181 | Accuracy: 0.9948
# Progress: 13% | Loss: 0.0170 | Accuracy: 0.9952
# Progress: 14% | Loss: 0.0173 | Accuracy: 0.9950
# Progress: 15% | Loss: 0.0166 | Accuracy: 0.9950
# Progress: 16% | Loss: 0.0169 | Accuracy: 0.9951
# Progress: 17% | Loss: 0.0165 | Accuracy: 0.9954
# Progress: 18% | Loss: 0.0184 | Accuracy: 0.9945
# Progress: 19% | Loss: 0.0180 | Accuracy: 0.9948
# Progress: 20% | Loss: 0.0173 | Accuracy: 0.9950
# Progress: 21% | Loss: 0.0166 | Accuracy: 0.9953
# Progress: 22% | Loss: 0.0161 | Accuracy: 0.9955
# Progress: 23% | Loss: 0.0157 | Accuracy: 0.9955
# Progress: 24% | Loss: 0.0153 | Accuracy: 0.9957
# Progress: 25% | Loss: 0.0148 | Accuracy: 0.9959
# Progress: 26% | Loss: 0.0145 | Accuracy: 0.9959
# Progress: 27% | Loss: 0.0147 | Accuracy: 0.9957
# Progress: 28% | Loss: 0.0148 | Accuracy: 0.9956
# Progress: 29% | Loss: 0.0149 | Accuracy: 0.9953
# Progress: 30% | Loss: 0.0150 | Accuracy: 0.9953
# Progress: 31% | Loss: 0.0148 | Accuracy: 0.9953
# Progress: 32% | Loss: 0.0158 | Accuracy: 0.9952
# Progress: 33% | Loss: 0.0156 | Accuracy: 0.9951
# Progress: 34% | Loss: 0.0153 | Accuracy: 0.9952
# Progress: 35% | Loss: 0.0149 | Accuracy: 0.9954
# Progress: 36% | Loss: 0.0146 | Accuracy: 0.9955
# Progress: 37% | Loss: 0.0142 | Accuracy: 0.9956
# Progress: 38% | Loss: 0.0143 | Accuracy: 0.9955
# Progress: 39% | Loss: 0.0145 | Accuracy: 0.9955
# Progress: 40% | Loss: 0.0146 | Accuracy: 0.9953
# Progress: 41% | Loss: 0.0146 | Accuracy: 0.9953
# Progress: 42% | Loss: 0.0146 | Accuracy: 0.9953
# Progress: 43% | Loss: 0.0154 | Accuracy: 0.9951
# Progress: 44% | Loss: 0.0154 | Accuracy: 0.9950
# Progress: 45% | Loss: 0.0155 | Accuracy: 0.9948
# Progress: 46% | Loss: 0.0154 | Accuracy: 0.9948
# Progress: 47% | Loss: 0.0157 | Accuracy: 0.9946
# Progress: 48% | Loss: 0.0156 | Accuracy: 0.9946
# Progress: 49% | Loss: 0.0154 | Accuracy: 0.9946
# Progress: 50% | Loss: 0.0155 | Accuracy: 0.9945
# Progress: 51% | Loss: 0.0165 | Accuracy: 0.9944
# Progress: 52% | Loss: 0.0163 | Accuracy: 0.9945
# Progress: 53% | Loss: 0.0163 | Accuracy: 0.9944
# Progress: 54% | Loss: 0.0164 | Accuracy: 0.9944
# Progress: 55% | Loss: 0.0166 | Accuracy: 0.9943
# Progress: 56% | Loss: 0.0164 | Accuracy: 0.9944
# Progress: 57% | Loss: 0.0162 | Accuracy: 0.9945
# Progress: 58% | Loss: 0.0162 | Accuracy: 0.9944
# Progress: 59% | Loss: 0.0163 | Accuracy: 0.9943
# Progress: 60% | Loss: 0.0165 | Accuracy: 0.9943
# Progress: 61% | Loss: 0.0163 | Accuracy: 0.9943
# Progress: 62% | Loss: 0.0161 | Accuracy: 0.9944
# Progress: 63% | Loss: 0.0159 | Accuracy: 0.9945
# Progress: 64% | Loss: 0.0159 | Accuracy: 0.9944
# Progress: 65% | Loss: 0.0159 | Accuracy: 0.9944
# Progress: 66% | Loss: 0.0158 | Accuracy: 0.9944
# Progress: 67% | Loss: 0.0161 | Accuracy: 0.9942
# Progress: 68% | Loss: 0.0159 | Accuracy: 0.9943
# Progress: 69% | Loss: 0.0161 | Accuracy: 0.9943
# Progress: 70% | Loss: 0.0160 | Accuracy: 0.9943
# Progress: 71% | Loss: 0.0160 | Accuracy: 0.9943
# Progress: 72% | Loss: 0.0158 | Accuracy: 0.9944
# Progress: 73% | Loss: 0.0161 | Accuracy: 0.9944
# Progress: 74% | Loss: 0.0160 | Accuracy: 0.9943
# Progress: 75% | Loss: 0.0159 | Accuracy: 0.9944
# Progress: 76% | Loss: 0.0158 | Accuracy: 0.9945
# Progress: 77% | Loss: 0.0161 | Accuracy: 0.9944
# Progress: 78% | Loss: 0.0160 | Accuracy: 0.9944
# Progress: 79% | Loss: 0.0164 | Accuracy: 0.9944
# Progress: 80% | Loss: 0.0163 | Accuracy: 0.9944
# Progress: 81% | Loss: 0.0164 | Accuracy: 0.9943
# Progress: 82% | Loss: 0.0164 | Accuracy: 0.9943
# Progress: 83% | Loss: 0.0162 | Accuracy: 0.9944
# Progress: 84% | Loss: 0.0163 | Accuracy: 0.9944
# Progress: 85% | Loss: 0.0162 | Accuracy: 0.9944
# Progress: 86% | Loss: 0.0160 | Accuracy: 0.9945
# Progress: 87% | Loss: 0.0162 | Accuracy: 0.9944
# Progress: 88% | Loss: 0.0162 | Accuracy: 0.9944
# Progress: 89% | Loss: 0.0161 | Accuracy: 0.9945
# Progress: 90% | Loss: 0.0164 | Accuracy: 0.9944
# Progress: 91% | Loss: 0.0164 | Accuracy: 0.9943
# Progress: 92% | Loss: 0.0165 | Accuracy: 0.9943
# Progress: 93% | Loss: 0.0165 | Accuracy: 0.9943
# Progress: 94% | Loss: 0.0164 | Accuracy: 0.9943
# Progress: 95% | Loss: 0.0162 | Accuracy: 0.9944
# Progress: 96% | Loss: 0.0161 | Accuracy: 0.9944
# Progress: 97% | Loss: 0.0163 | Accuracy: 0.9944
# Progress: 98% | Loss: 0.0163 | Accuracy: 0.9943
# Progress: 99% | Loss: 0.0165 | Accuracy: 0.9942
# Progress: 100% | Loss: 0.0165 | Accuracy: 0.9939
#   Training completed in 314.92 seconds.
# Epoch 12: Evaluating (Validation)...
# Progress: 1% | Loss: 0.0731 | Accuracy: 0.9833
# Progress: 2% | Loss: 0.0785 | Accuracy: 0.9722
# Progress: 3% | Loss: 0.1099 | Accuracy: 0.9615
# Progress: 4% | Loss: 0.0883 | Accuracy: 0.9676
# Progress: 5% | Loss: 0.0789 | Accuracy: 0.9697
# Progress: 6% | Loss: 0.1055 | Accuracy: 0.9679
# Progress: 7% | Loss: 0.1118 | Accuracy: 0.9704
# Progress: 8% | Loss: 0.1344 | Accuracy: 0.9667
# Progress: 9% | Loss: 0.1207 | Accuracy: 0.9701
# Progress: 10% | Loss: 0.1164 | Accuracy: 0.9697
# Progress: 11% | Loss: 0.1310 | Accuracy: 0.9653
# Progress: 12% | Loss: 0.1279 | Accuracy: 0.9647
# Progress: 13% | Loss: 0.1659 | Accuracy: 0.9605
# Progress: 14% | Loss: 0.1635 | Accuracy: 0.9617
# Progress: 15% | Loss: 0.1671 | Accuracy: 0.9590
# Progress: 16% | Loss: 0.1591 | Accuracy: 0.9601
# Progress: 17% | Loss: 0.1488 | Accuracy: 0.9628
# Progress: 18% | Loss: 0.1502 | Accuracy: 0.9637
# Progress: 19% | Loss: 0.1494 | Accuracy: 0.9644
# Progress: 20% | Loss: 0.1493 | Accuracy: 0.9646
# Progress: 21% | Loss: 0.1484 | Accuracy: 0.9643
# Progress: 22% | Loss: 0.1422 | Accuracy: 0.9658
# Progress: 23% | Loss: 0.1380 | Accuracy: 0.9658
# Progress: 24% | Loss: 0.1327 | Accuracy: 0.9671
# Progress: 25% | Loss: 0.1401 | Accuracy: 0.9660
# Progress: 26% | Loss: 0.1356 | Accuracy: 0.9668
# Progress: 27% | Loss: 0.1389 | Accuracy: 0.9658
# Progress: 28% | Loss: 0.1469 | Accuracy: 0.9642
# Progress: 29% | Loss: 0.1514 | Accuracy: 0.9633
# Progress: 30% | Loss: 0.1478 | Accuracy: 0.9641
# Progress: 31% | Loss: 0.1532 | Accuracy: 0.9627
# Progress: 32% | Loss: 0.1554 | Accuracy: 0.9626
# Progress: 33% | Loss: 0.1578 | Accuracy: 0.9615
# Progress: 34% | Loss: 0.1562 | Accuracy: 0.9615
# Progress: 35% | Loss: 0.1570 | Accuracy: 0.9608
# Progress: 36% | Loss: 0.1564 | Accuracy: 0.9615
# Progress: 37% | Loss: 0.1660 | Accuracy: 0.9599
# Progress: 38% | Loss: 0.1672 | Accuracy: 0.9593
# Progress: 39% | Loss: 0.1627 | Accuracy: 0.9606
# Progress: 40% | Loss: 0.1624 | Accuracy: 0.9605
# Progress: 41% | Loss: 0.1656 | Accuracy: 0.9590
# Progress: 42% | Loss: 0.1716 | Accuracy: 0.9583
# Progress: 43% | Loss: 0.1703 | Accuracy: 0.9583
# Progress: 44% | Loss: 0.1672 | Accuracy: 0.9588
# Progress: 45% | Loss: 0.1639 | Accuracy: 0.9596
# Progress: 46% | Loss: 0.1642 | Accuracy: 0.9598
# Progress: 47% | Loss: 0.1641 | Accuracy: 0.9598
# Progress: 48% | Loss: 0.1634 | Accuracy: 0.9601
# Progress: 49% | Loss: 0.1653 | Accuracy: 0.9603
# Progress: 50% | Loss: 0.1625 | Accuracy: 0.9610
# Progress: 51% | Loss: 0.1635 | Accuracy: 0.9602
# Progress: 52% | Loss: 0.1631 | Accuracy: 0.9604
# Progress: 53% | Loss: 0.1644 | Accuracy: 0.9600
# Progress: 54% | Loss: 0.1657 | Accuracy: 0.9599
# Progress: 55% | Loss: 0.1623 | Accuracy: 0.9608
# Progress: 56% | Loss: 0.1619 | Accuracy: 0.9611
# Progress: 57% | Loss: 0.1596 | Accuracy: 0.9617
# Progress: 58% | Loss: 0.1608 | Accuracy: 0.9617
# Progress: 59% | Loss: 0.1638 | Accuracy: 0.9608
# Progress: 60% | Loss: 0.1632 | Accuracy: 0.9611
# Progress: 61% | Loss: 0.1700 | Accuracy: 0.9598
# Progress: 62% | Loss: 0.1681 | Accuracy: 0.9599
# Progress: 63% | Loss: 0.1659 | Accuracy: 0.9602
# Progress: 64% | Loss: 0.1661 | Accuracy: 0.9601
# Progress: 65% | Loss: 0.1665 | Accuracy: 0.9600
# Progress: 66% | Loss: 0.1661 | Accuracy: 0.9602
# Progress: 67% | Loss: 0.1714 | Accuracy: 0.9593
# Progress: 68% | Loss: 0.1694 | Accuracy: 0.9598
# Progress: 69% | Loss: 0.1676 | Accuracy: 0.9600
# Progress: 70% | Loss: 0.1665 | Accuracy: 0.9603
# Progress: 71% | Loss: 0.1666 | Accuracy: 0.9604
# Progress: 72% | Loss: 0.1653 | Accuracy: 0.9606
# Progress: 73% | Loss: 0.1654 | Accuracy: 0.9606
# Progress: 74% | Loss: 0.1674 | Accuracy: 0.9606
# Progress: 75% | Loss: 0.1660 | Accuracy: 0.9606
# Progress: 76% | Loss: 0.1660 | Accuracy: 0.9604
# Progress: 77% | Loss: 0.1677 | Accuracy: 0.9603
# Progress: 78% | Loss: 0.1687 | Accuracy: 0.9599
# Progress: 79% | Loss: 0.1681 | Accuracy: 0.9599
# Progress: 80% | Loss: 0.1676 | Accuracy: 0.9601
# Progress: 81% | Loss: 0.1669 | Accuracy: 0.9605
# Progress: 82% | Loss: 0.1669 | Accuracy: 0.9607
# Progress: 83% | Loss: 0.1665 | Accuracy: 0.9607
# Progress: 84% | Loss: 0.1681 | Accuracy: 0.9605
# Progress: 85% | Loss: 0.1678 | Accuracy: 0.9607
# Progress: 86% | Loss: 0.1685 | Accuracy: 0.9605
# Progress: 87% | Loss: 0.1686 | Accuracy: 0.9604
# Progress: 88% | Loss: 0.1670 | Accuracy: 0.9607
# Progress: 89% | Loss: 0.1657 | Accuracy: 0.9609
# Progress: 90% | Loss: 0.1643 | Accuracy: 0.9611
# Progress: 91% | Loss: 0.1642 | Accuracy: 0.9612
# Progress: 92% | Loss: 0.1637 | Accuracy: 0.9612
# Progress: 93% | Loss: 0.1643 | Accuracy: 0.9609
# Progress: 94% | Loss: 0.1624 | Accuracy: 0.9614
# Progress: 95% | Loss: 0.1640 | Accuracy: 0.9614
# Progress: 96% | Loss: 0.1626 | Accuracy: 0.9618
# Progress: 97% | Loss: 0.1633 | Accuracy: 0.9616
# Progress: 98% | Loss: 0.1619 | Accuracy: 0.9620
# Progress: 99% | Loss: 0.1619 | Accuracy: 0.9619
# Progress: 100% | Loss: 0.1608 | Accuracy: 0.9617
#   Validation completed in 23.64 seconds.
# Epoch 12/12:
#   Train Loss: 0.0165 | Train Accuracy: 0.9942
#   Val Loss: 0.1608 | Val Accuracy: 0.9621
#   Saved best model to /kaggle/working/best_model_epoch_12_val_acc_0.9621.pth
#
# ===== Training Completed =====
# Final Train Loss: 0.0165 | Final Train Accuracy: 0.9942
# Final Val Loss: 0.1608 | Final Val Accuracy: 0.9621

# %%
#------------------------ Vẽ biểu đồ kết quả------------------------------------
trainer.plot_metrics() # kết quả biểu đồ

# %% [markdown]
# **Test**

# %%
# class CustomELECTRAModel(nn.Module):
#     def __init__(self, model_name, num_labels=2):
#         super(CustomELECTRAModel, self).__init__()
#         self.electra = ElectraModel.from_pretrained(model_name)
#         self.attention = nn.MultiheadAttention(
#             embed_dim=self.electra.config.hidden_size, 
#             num_heads=8, 
#             batch_first=True
#         )
#         self.fc1 = nn.Linear(self.electra.config.hidden_size, 128)
#         self.fc2 = nn.Linear(128, num_labels)
#         self.dropout = nn.Dropout(0.3)
#         # Thêm lớp LayerNorm
#         self.layer_norm = nn.LayerNorm(128)

#     def forward(self, input_ids, attention_mask):
#         # Trích xuất embeddings từ ELECTRA
#         outputs = self.electra(input_ids=input_ids, attention_mask=attention_mask)
#         hidden_states = outputs.last_hidden_state  # Shape: (batch_size, seq_len, hidden_size)
#         # Attention pooling
#         attn_output, _ = self.attention(hidden_states, hidden_states, hidden_states, key_padding_mask=~attention_mask.bool())
#         # Chọn CLS token làm đặc trưng đại diện
#         cls_token_output = attn_output[:, 0, :]  # CLS token tương ứng với đầu tiên của sequence output
#         # Fully connected layers
#         pooled_output = self.dropout(cls_token_output)  # Áp dụng dropout
#         fc1_output = torch.relu(self.fc1(pooled_output))
#         # Áp dụng Layer Normalization sau FC1
#         fc1_output = self.layer_norm(fc1_output)
#         logits = self.fc2(fc1_output)
#         return logits
# # Tải mô hình ELECTRA-Base
# model_name='google/electra-base-discriminator' 
# tokenizer = ElectraTokenizer.from_pretrained(model_name)

# model_path = '/kaggle/input/model-test-sentiment-electra-v4/best_model_epoch_7_val_acc_0.9480.pth'
# # Load the trained model weights
# # model = CustomELECTRAModel(model_name=model_name)
# model = torch.load(model_path, map_location=torch.device('cuda'))
# # model.to('cuda' if torch.cuda.is_available() else 'cpu')
# model.eval()

# %%
from sklearn.utils import shuffle
from sklearn.metrics import ConfusionMatrixDisplay
class SimplePredictor:
    def __init__(self, model, tokenizer, max_length=128, device='cuda'):
        self.model = model
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.device = device
    
    def predict_label(self, text):
        # Tokenize văn bản với độ dài tối đa
        encoding = self.tokenizer(
            text,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )
        
        input_ids = encoding['input_ids'].to(self.device)
        attention_mask = encoding['attention_mask'].to(self.device)
        
        # Chuyển sang chế độ đánh giá
        self.model.eval()
        with torch.no_grad():
            logits = self.model(input_ids=input_ids, attention_mask=attention_mask)
            prediction = torch.argmax(logits, dim=-1).item()
        
        return prediction

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Tạo đối tượng dự đoán
predictor = SimplePredictor(model, tokenizer, max_length=128, device=device)
# Tạo danh sách lưu các dòng dự đoán sai
mismatch_samples = []
augmented_data = []  # Danh sách lưu dữ liệu được nhân bản

# Dự đoán trên tập test và lưu mẫu dự đoán sai
y_true = test_data['label'].tolist()
y_pred = []
mismatch_samples = []

for idx, text in enumerate(tqdm(test_data['comment'], desc="Predicting on test data")):
    pred_label = predictor.predict_label(text)
    y_pred.append(pred_label)
    if pred_label != y_true[idx]:
        mismatch_samples.append({"Index": idx, "Text": text, "True Label": y_true[idx], "Predicted Label": pred_label})

# Lưu kết quả dự đoán sai ra file CSV
mismatch_samples_df = pd.DataFrame(mismatch_samples)
mismatch_samples_df.to_csv("/kaggle/working/mismatch_samples.csv", index=False, encoding='utf-8')
print("Mismatched samples saved to 'mismatch_samples.csv'")

# In báo cáo kết quả với 2 chữ số thập phân
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=["Positive", "Negative"], digits=4))

# Tạo ma trận nhầm lẫn
conf_matrix = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=["Positive", "Negative"])

# Vẽ ma trận nhầm lẫn
plt.figure(figsize=(8, 6))
disp.plot(cmap=plt.cm.Blues, values_format="d")
plt.title("Confusion Matrix")
plt.show()

# # Xử lý các mẫu dự đoán sai
# print("\nMismatched Samples:")
# for sample_idx, (idx, text, true_label, pred_label) in enumerate(mismatch_samples):
#     print(f"{sample_idx + 1}. Text: {text}")
#     print(f"   True Label: {'Positive' if true_label == 0 else 'Negative'}")
#     print(f"   Predicted Label: {'Positive' if pred_label == 0 else 'Negative'}")
    
#     # Hỏi người dùng có muốn đổi nhãn hay không
#     while True:
#         user_input = input("Change label? (1: Yes, 0: No): ")
#         if user_input in ['0', '1']:
#             user_input = int(user_input)
#             break
#         print("Invalid input! Please enter 1 (Yes) or 0 (No).")
    
#     # Nếu người dùng chọn đổi nhãn, cập nhật nhãn mới
#     if user_input == 1:
#         updated_labels[idx] = 1 - true_label  # Đổi nhãn 0 thành 1, hoặc 1 thành 0
#         print("Label updated.\n")
#     else:
#         # Nhân bản mẫu hiện tại thêm 5 lần
#         for _ in range(5):
#             augmented_data.append((text, true_label))
#         print("Data augmented 5 times.\n")

# # Tạo DataFrame từ dữ liệu nhân bản
# augmented_df = pd.DataFrame(augmented_data, columns=['comment', 'label'])

# # Gộp dữ liệu gốc và dữ liệu nhân bản
# test_data['label'] = updated_labels  # Cập nhật nhãn trong DataFrame
# final_data = pd.concat([test_data, augmented_df], ignore_index=True)

# # Xáo trộn dữ liệu
# final_data = shuffle(final_data, random_state=42)

# # Lưu lại dữ liệu đã cập nhật vào file .csv
# output_path = "/kaggle/working/dataset_process_v4.csv"
# final_data.to_csv(output_path, index=False, encoding='utf-8')
# print(f"Updated and augmented data saved to {output_path}.")
# Out:
# Predicting on test data: 100%|██████████| 5171/5171 [00:55<00:00, 93.78it/s]
# Mismatched samples saved to 'mismatch_samples.csv'
# Classification Report:
#               precision    recall  f1-score   support
#
#     Positive     0.9649    0.9582    0.9615      2581
#     Negative     0.9586    0.9653    0.9619      2590
#
#     accuracy                         0.9617      5171
#    macro avg     0.9617    0.9617    0.9617      5171
# weighted avg     0.9617    0.9617    0.9617      5171

# %% [markdown]
# # **Test với bài báo thực tế**

# %%
# from transformers import AutoTokenizer, AutoModelForTokenClassification
# from transformers import pipeline
# import re
# import os

# device = torch.device('cuda')
# tokenizer = AutoTokenizer.from_pretrained("NlpHUST/vi-word-segmentation")
# model_seg = AutoModelForTokenClassification.from_pretrained("NlpHUST/vi-word-segmentation").to(device)

# nlp = pipeline("token-classification", model=model_seg, tokenizer=tokenizer)

# %%
# def word_weg(text, nlp):
#   ner_results = nlp(text)
#   example_tok = ""
#   for e in ner_results:
#       if "##" in e["word"]:
#           example_tok = example_tok + e["word"].replace("##","")
#       elif e["entity"] =="I":
#           example_tok = example_tok + "_" + e["word"]
#       elif ("." in e["word"]) or ("/" in e["word"]) or ("%" in e["word"]) or ("-" in e["word"]):
#         example_tok = example_tok + "" + e["word"]
#       else:
#         example_tok = example_tok + " " + e["word"]
#   return example_tok
    
# # Hàm tiền xử lý cho text
# def preprocessing_text(text, nlp):
#     # lower text
#     text = text.lower()

#     # remove special char
#     allowed_special_chars = r"\%-/"
#     allowed_chars = r"[^a-zA-Z0-9\s" + re.escape(allowed_special_chars) + r"àáạảãâầấậẩẫăằắặẳẵèéẹẻẽêềếệểễìíịỉĩòóọỏõôồốộổỗơờớợởỡùúụủũưừứựửữỳýỵỷỹđÀÁẠẢÃÂẦẤẬẨẪĂẰẮẶẲẴÈÉẸẺẼÊỀẾỆỂỄÌÍỊỈĨÒÓỌỎÕÔỒỐỘỔỖƠỜỚỢỞỠÙÚỤỦŨƯỪỨỰỬỮỲÝỴỶỸĐ]"
#     text = re.sub(allowed_chars, '', text)

#     # word segmentor
#     text = word_weg(text, nlp)

#     # remove stop word
#     with open('/kaggle/input/model-test/vietnamese.txt', 'r', encoding='utf-8') as f:
#         stop_words = set(f.read().strip().split('\n'))
#     words = text.split()
#     filtered_words = [word for word in words if word not in stop_words]
#     text =' '.join(filtered_words)

#     return text

# def split_sentence_into_chunks(sentence, max_length=512):
#     """Cắt câu dài thành các đoạn nhỏ hơn hoặc bằng max_length ký tự."""
#     chunks = []
#     while len(sentence) > max_length:
#         # Tìm vị trí dấu cách gần nhất trước giới hạn max_length
#         split_pos = sentence[:max_length].rfind(" ")
#         if split_pos == -1:  # Nếu không tìm thấy dấu cách
#             split_pos = max_length
#         chunks.append(sentence[:split_pos].strip())
#         sentence = sentence[split_pos:].strip()
#     if sentence:  # Thêm phần còn lại của câu
#         chunks.append(sentence)
#     return chunks

# def split_text_with_long_sentences(text, max_length=512):
#     """Cắt văn bản thành nhiều đoạn nhỏ hơn hoặc bằng max_length ký tự, bao gồm cả câu dài."""
#     text = text.strip()
#     sentences = re.split(r'(?<=[.])', text)  # Tách theo câu, giữ lại dấu chấm
#     chunks = []
#     for sentence in sentences:
#         sentence = sentence.strip()
#         if len(sentence) > max_length:
#             # Nếu câu vượt quá max_length, cắt thành các đoạn nhỏ
#             chunks.extend(split_sentence_into_chunks(sentence, max_length))
#         else:
#             # Nếu câu không vượt quá max_length, thêm vào danh sách
#             chunks.append(sentence)
#     return chunks
    
# def preprocessing_data(text, nlp):
    
#     sentences = split_text_with_long_sentences(text, max_length=512)
    
#     # Loại bỏ các câu rỗng hoặc chỉ chứa khoảng trắng
#     sentences = [sentence.strip() for sentence in sentences if sentence.strip()]
    
#     # Nối kết quả sau xử lý bằng dấu cách
#     text = " ".join(preprocessing_text(sentence, nlp) for sentence in sentences)
#     return text
    


# def classify_article_with_percentage(article_text):
#     """
#     Hàm nhận diện tin giả cho một bài báo và trả về nhãn cùng tỷ lệ phần trăm dự đoán.
    
#     Args:
#         article_text (str): Nội dung bài báo cần phân loại.
        
#     Returns:
#         str: Kết quả phân loại ("Real" hoặc "Fake").
#         dict: Tỷ lệ phần trăm dự đoán cho từng nhãn.
#     """
#     # Lấy các dự đoán từ các cửa sổ trượt
#     token_windows = predictor.sliding_window_tokenize(article_text)
#     predictions = []
#     predictor.model.eval()
#     with torch.no_grad():
#         for window in token_windows:
#             inputs = {
#                 'input_ids': torch.tensor([window]).to(predictor.device),
#                 'attention_mask': torch.tensor([[1 if token != predictor.tokenizer.pad_token_id else 0 for token in window]]).to(predictor.device)
#             }
#             logits = predictor.model.forward(inputs['input_ids'], inputs['attention_mask'])
#             predictions.append(torch.argmax(logits, dim=1).item())
    
#     # Tính tỷ lệ phần trăm
#     label_count = Counter(predictions)
#     total_windows = len(predictions)
#     percentage = {label: (count / total_windows) * 100 for label, count in label_count.items()}
    
#     # Quyết định nhãn cuối cùng
#     if label_count[0] == label_count[1]:
#         final_label = 1
#     else:
#         final_label = label_count.most_common(1)[0][0]
    
#     return "Real" if final_label == 0 else "Fake", percentage

# %%
# # Nhập nội dunng bài báo

# text="""Theo Luật sửa đổi, doanh nghiệp tiếp tục đóng 2% quỹ tiền lương làm căn cứ đóng bảo hiểm xã hội cho nhân viên vào quỹ công đoàn
# """



# print("/nNội dung bài báo gốc: ",text)

# text_process=preprocessing_data(text,nlp)
# print("\nNội dung bài báo đã tiền xử lý: ",text_process)

# article_text= text_process

# # Phân loại bài báo và lấy tỷ lệ phần trăm
# result, percentages = classify_article_with_percentage(article_text)

# print(f"\nKết quả nhận diện: {result}")
# print(f"\nTỷ lệ dự đoán: Real = {percentages.get(0, 0):.2f}%, Fake = {percentages.get(1, 0):.2f}%")
